# %%
import sys

# %%
sys.version
# Out:
# '3.12.3 (main, Mar 10 2026, 12:34:10) [GCC 13.3.0]'

# %%
sys.path
# Out:
# ['/home/gp21012/.pyenv/versions/3.12.3/lib/python312.zip',
#  '/home/gp21012/.pyenv/versions/3.12.3/lib/python3.12',
#  '/home/gp21012/.pyenv/versions/3.12.3/lib/python3.12/lib-dynload',
#  '',
#  '/home/gp21012/.cache/pypoetry/virtualenvs/dve-sample-py-1sUhEi8s-py3.12/lib/python3.12/site-packages',
#  '/home/gp21012/work/vs/dve-sample-py/src']

# %%
import pkg_resources
installed_packages = pkg_resources.working_set
installed_packages_list = sorted(["%s==%s" % (i.key, i.version)
     for i in installed_packages])
print(installed_packages_list)
# Out:
# ['absl-py==2.1.0', 'alabaster==1.0.0', 'altair==5.5.0', 'anyio==4.8.0', 'argon2-cffi-bindings==21.2.0', 'argon2-cffi==23.1.0', 'argparse==1.4.0', 'array-record==0.6.0', 'arrow==1.3.0', 'astroid==3.3.8', 'asttokens==3.0.0', 'astunparse==1.6.3', 'async-lru==2.0.4', 'attrs==24.3.0', 'autocommand==2.2.2', 'autopep8==2.3.2', 'babel==2.16.0', 'backports.tarfile==1.2.0', 'beautifulsoup4==4.12.3', 'black==24.10.0', 'bleach==6.2.0', 'blinker==1.9.0', 'bump2version==1.0.1', 'bumpversion==0.6.0', 'certifi==2024.12.14', 'cffi==1.17.1', 'charset-normalizer==3.4.1', 'click==8.1.8', 'colorama==0.4.6', 'comm==0.2.2', 'contourpy==1.3.1', 'coverage==7.6.10', 'cryptography==44.0.0', 'cuda-bindings==13.0.3', 'cuda-pathfinder==1.4.1', 'cycler==0.12.1', 'debugpy==1.8.11', 'decorator==5.1.1', 'defusedxml==0.7.1', 'dill==0.3.9', 'dm-tree==0.1.8', 'docopt==0.6.2', 'docstring-parser==0.16', 'docstring-to-markdown==0.15', 'docutils==0.21.2', 'dve-sample-py==2.1.0a1', 'et-xmlfile==2.0.0', 'etils==1.11.0', 'executing==2.1.0', 'fastjsonschema==2.21.1', 'filelock==3.17.0', 'flake8==7.1.1', 'flask==3.1.0', 'flatbuffers==24.12.23', 'fonttools==4.55.3', 'fqdn==1.5.1', 'fsspec==2024.12.0', 'gast==0.6.0', 'google-pasta==0.2.0', 'googleapis-common-protos==1.66.0', 'graphframes==0.6', 'graphviz==0.20.3', 'greenlet==3.1.1', 'grpcio==1.69.0', 'h11==0.14.0', 'h5py==3.12.1', 'httpcore==1.0.7', 'httpx==0.28.1', 'icecream==2.1.4', 'idna==3.10', 'igraph==0.11.8', 'imagesize==1.4.1', 'immutabledict==4.2.1', 'importlib-metadata==8.0.0', 'importlib-resources==6.5.2', 'inflect==7.3.1', 'iniconfig==2.0.0', 'ipykernel==6.29.5', 'ipython-bg==0.2', 'ipython==8.31.0', 'ipywidgets==8.1.5', 'iso3166==2.1.1', 'isoduration==20.11.0', 'isort==5.13.2', 'itsdangerous==2.2.0', 'jaraco.classes==3.4.0', 'jaraco.collections==5.1.0', 'jaraco.context==6.0.1', 'jaraco.functools==4.1.0', 'jaraco.text==3.12.1', 'jedi==0.19.2', 'jeepney==0.8.0', 'jinja2==3.1.5', 'joblib==1.4.2', 'json5==0.10.0', 'jsonpickle==4.0.1', 'jsonpointer==3.0.0', 'jsonschema-specifications==2024.10.1', 'jsonschema==4.23.0', 'jupyter-client==8.6.3', 'jupyter-console==6.6.3', 'jupyter-core==5.7.2', 'jupyter-events==0.11.0', 'jupyter-lsp==2.2.5', 'jupyter-server-terminals==0.5.3', 'jupyter-server==2.15.0', 'jupyter==1.1.1', 'jupyterlab-lsp==5.1.0', 'jupyterlab-pygments==0.3.0', 'jupyterlab-server==2.27.3', 'jupyterlab-widgets==3.0.13', 'jupyterlab==4.3.4', 'jupytext==1.16.6', 'keras==3.8.0', 'keyring==25.6.0', 'kiwisolver==1.4.8', 'libclang==18.1.1', 'linecache2==1.0.0', 'lux-api==0.5.1', 'lux-widget==0.1.11', 'lxml==5.3.0', 'markdown-it-py==3.0.0', 'markdown==3.7', 'markupsafe==3.0.2', 'matplotlib-inline==0.1.7', 'matplotlib==3.10.0', 'mccabe==0.7.0', 'mdit-py-plugins==0.4.2', 'mdurl==0.1.2', 'mistune==3.1.0', 'ml-dtypes==0.4.1', 'mock==5.1.0', 'more-itertools==10.6.0', 'mpmath==1.3.0', 'mypy-extensions==1.0.0', 'mypy==1.14.1', 'mysql-connector-python==9.1.0', 'mysqlclient==2.2.7', 'namex==0.0.8', 'narwhals==1.22.0', 'nbclient==0.10.2', 'nbconvert==7.16.5', 'nbformat==5.10.4', 'nbsphinx==0.9.6', 'nest-asyncio==1.6.0', 'networkx==3.4.2', 'nh3==0.2.20', 'nodeenv==1.9.1', 'nodejs==0.1.1', 'nose==1.3.7', 'notebook-shim==0.2.4', 'notebook==7.3.2', 'numpy==2.0.2', 'nvidia-cublas-cu12==12.1.3.1', 'nvidia-cublas==13.1.0.3', 'nvidia-cuda-cupti-cu12==12.1.105', 'nvidia-cuda-cupti==13.0.85', 'nvidia-cuda-nvrtc-cu12==12.1.105', 'nvidia-cuda-nvrtc==13.0.88', 'nvidia-cuda-runtime-cu12==12.1.105', 'nvidia-cuda-runtime==13.0.96', 'nvidia-cudnn-cu12==9.1.0.70', 'nvidia-cudnn-cu13==9.15.1.9', 'nvidia-cufft-cu12==11.0.2.54', 'nvidia-cufft==12.0.0.61', 'nvidia-cufile==1.15.1.6', 'nvidia-curand-cu12==10.3.2.106', 'nvidia-curand==10.4.0.35', 'nvidia-cusolver-cu12==11.4.5.107', 'nvidia-cusolver==12.0.4.66', 'nvidia-cusparse-cu12==12.1.0.106', 'nvidia-cusparse==12.6.3.3', 'nvidia-cusparselt-cu13==0.8.0', 'nvidia-ml-py==12.570.86', 'nvidia-nccl-cu12==2.20.5', 'nvidia-nccl-cu13==2.28.9', 'nvidia-nvjitlink-cu12==12.8.61', 'nvidia-nvjitlink==13.0.88', ...
# /tmp/ipykernel_454208/197848495.py:1: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   import pkg_resources

# %%
# %env
# Out:
# {'SHELL': '/bin/bash',
#  'NV_LIBCUBLAS_VERSION': '11.11.3.6-1',
#  'NVIDIA_VISIBLE_DEVICES': 'all',
#  'NV_NVML_DEV_VERSION': '11.8.86-1',
#  'NV_CUDNN_PACKAGE_NAME': 'libcudnn8',
#  'PYENV_SHELL': 'bash',
#  'USERID': '0',
#  'GLOBAL_VENV': '/opt/pyvenvs/global',
#  'NV_LIBNCCL_DEV_PACKAGE': 'libnccl-dev=2.15.5-1+cuda11.8',
#  'GROUPID': '0',
#  'FNM_ARCH': 'x64',
#  'NV_LIBNCCL_DEV_PACKAGE_VERSION': '2.15.5-1',
#  'R_HOME': '/usr/local/lib/R',
#  'HOSTNAME': '09c42182467d',
#  'X_RC_SYSPROFILE_INCLUDED': '1',
#  'NVIDIA_REQUIRE_CUDA': 'cuda>=11.8 brand=tesla,driver>=470,driver<471 brand=unknown,driver>=470,driver<471 brand=nvidia,driver>=470,driver<471 brand=nvidiartx,driver>=470,driver<471 brand=geforce,driver>=470,driver<471 brand=geforcertx,driver>=470,driver<471 brand=quadro,driver>=470,driver<471 brand=quadrortx,driver>=470,driver<471 brand=titan,driver>=470,driver<471 brand=titanrtx,driver>=470,driver<471',
#  'NV_LIBCUBLAS_DEV_PACKAGE': 'libcublas-dev-11-8=11.11.3.6-1',
#  'NV_NVTX_VERSION': '11.8.86-1',
#  'FNM_NODE_DIST_MIRROR': 'https://nodejs.org/dist',
#  'NV_CUDA_CUDART_DEV_VERSION': '11.8.89-1',
#  'NV_DRIVER_LINE': '470',
#  'NV_LIBCUSPARSE_VERSION': '11.7.5.86-1',
#  'X_AUTO_ENV': '1',
#  'NV_LIBNPP_VERSION': '11.8.0.86-1',
#  'NCCL_VERSION': '2.15.5-1',
#  'EDITOR': 'vim',
#  'PYENV_VERSION': '3.12.3',
#  'X_DEBUG_ENV': '',
#  'PWD': '/root/work/vs/dve-sample-r',
#  'PYENV_VIRTUALENV_INIT': '1',
#  'VIRTUAL_IMG': '/opt/venv.img',
#  'X_RC_Z93_PYENV': '1',
#  'NV_CUDNN_PACKAGE': 'libcudnn8=8.6.0.163-1+cuda11.8',
#  'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility',
#  'NV_NVCC_PACKAGE': 'cuda-nvcc-11-8',
#  'NV_NVPROF_DEV_PACKAGE': 'cuda-nvprof-11-8=11.8.87-1',
#  'NV_LIBNPP_PACKAGE': 'libnpp-11-8=11.8.0.86-1',
#  'NV_LIBNCCL_DEV_PACKAGE_NAME': 'libnccl-dev',
#  'TZ': 'Europe/Rome',
#  'NV_LIBCUBLAS_DEV_VERSION': '11.11.3.6-1',
#  'container': 'podman',
#  'NVIDIA_PRODUCT_NAME': 'CUDA',
#  'NVIDIA_CPU_ONLY': '1',
#  'NV_LIBCUBLAS_DEV_PACKAGE_NAME': 'libcublas-dev-11-8',
#  'NV_CUDA_CUDART_VERSION': '11.8.89-1',
#  'X_RC_SYSPROFILE_INCLUDING': '1',
#  'HOME': '/root',
#  'LANG': 'en_US.UTF-8',
#  'S6_VERSION': 'v2.1.0.2',
#  'FNM_COREPACK_ENABLED': 'false',
#  'CARGO_HOME': '/opt/cargo',
#  'X_WORK_DIR': '/root/./work/vs/dve-sample-r',
#  'NV_NVINFER_PACKAGE_ALIAS': 'libnvinfer7',
#  'VIRTUAL_ENV': '/root/.cache/pypoetry/virtualenvs/dve-sample-r-P4i7psD2-py3.12',
#  'CUDA_VERSION': '11.8.0',
#  'NV_LIBCUBLAS_PACKAGE': 'libcublas-11-8=11.11.3.6-1',
#  'NV_CUDA_NSIGHT_COMPUTE_DEV_PACKAGE': 'cuda-nsight-compute-11-8=11.8.0-1',
#  'PURGE_BUILDDEPS': 'false',
#  'RUSTUP_URL': 'https://sh.rustup.rs',
#  'X_RC_Z94_POETRY': '1',
#  'NV_LIBNPP_DEV_PACKAGE': 'libnpp-dev-11-8=11.8.0.86-1',
#  'NV_LIBCUBLAS_PACKAGE_NAME': 'libcublas-11-8',
#  'NV_NVINFER_PACKAGES': 'libnvinfer8=8.6.0.12-1+cuda11.8 libnvinfer-dev=8.6.0.12-1+cuda11.8 libnvinfer-headers-dev=8.6.0.12-1+cuda11.8 libnvinfer-headers-plugin-dev=8.6.0.12-1+cuda11.8 libnvinfer-plugin8=8.6.0.12-1+cuda11.8 libnvinfer-plugin-dev=8.6.0.12-1+cuda11.8',
#  'PASSWORD': '5gq2MQskQ45cJARF6Ci4qUwdnIahvUY9TYaFGmkrKl0q',
#  'NV_LIBNPP_DEV_VERSION': '11.8.0.86-1',
#  'RUST_ROOT': '/opt/rust',
#  'TERM': 'xterm-color',
#  'NV_LIBCUSPARSE_DEV_VERSION': '11.7.5.86-1',
#  'RUSTUP_HOME': '/opt/rust',
#  'NV_NVINFER_PACKAGE_LIST': 'libnvinfer8 libnvinfer-dev libnvinfer-headers-dev libnvinfer-headers-plugin-dev libnvinfer-plugin8 libnvinfer-plugin-dev',
#  'NV_DRIVER_DIST': '520',
#  'USER': 'root',
#  'CRAN': 'https://p3m.dev/cran/__linux__/jammy/latest',
#  'NODE_ROOT': '/opt/nodejs',
#  'LIBRARY_PATH': '/usr/local/cuda/lib64/stubs',
#  'NV_CUDNN_VERSION': '8.6.0.163',
#  'PYVENVS_ROOT': '/opt/pyvenvs',
#  'VISUAL': 'vim',
#  'ROOT': 'true',
#  'PYTHON_KEYRING_BACKEND': '<hidden>',
#  'PYTHON_CONFIGURE_OPTS': '--enable-shared',
#  'SHLVL': '0',
#  'PAGER': 'cat',
#  'NV_CUDA_LIB_VERSION': '11.8.0-1',
#  'NVARCH': 'x86_64',
#  'FNM_VERSION_FILE_STRATEGY': 'local',
#  'R_VERSION': '4.4.1',
#  'NV_CUDNN_PACKAGE_DEV': 'libcudnn8-dev=8.6.0.163-1+cuda11.8',
#  'PIPX_GLOBAL_HOME': '/opt/pipx',
#  'VIRTUAL_ENV_PROMPT': 'dve-sample-r-py3.12',
#  'PIPX_GLOBAL_BIN_DIR': '/opt/pipx/bin',
#  'NV_CUDA_COMPAT_PACKAGE': 'cuda-compat-11-8',
#  'NV_NVINFER_PACKAGE_NAME': 'libnvinfer8',
#  'NV_NVINFER_VER': '8.6.0.12-1+cuda11.8',
#  'RSTUDIO_VERSION': '2024.04.2+764',
#  'NV_LIBNCCL_PACKAGE': 'libnccl2=2.15.5-1+cuda11.8',
#  'LD_LIBRARY_PATH': '/usr/local/nvidia/lib:/usr/local/nvidia/lib64',
#  'FNM_ROOT': '/opt/fnm',
#  'FNM_RESOLVE_ENGINES': 'true',
#  'PS1': '(dve-sample-r-py3.12) ${debian_chroot:+($debian_chroot)}\\u@\\h:\\w\\$ ',
#  'PYENV_ROOT': '/opt/pyenv',
#  'NV_CUDA_NSIGHT_COMPUTE_VERSION': '11.8.0-1',
#  'DEBUGINFOD_URLS': '',
#  'NV_DRIVER_COMP': '470',
#  'NV_NVPROF_VERSION': '11.8.87-1',
#  'NV_CUDNN_PACKAGE_LIST': 'libcudnn8 libcudnn8-dev',
#  'RETICULATE_AUTOCONFIGURE': '0',
#  'POETRY_HOME': '/opt/poetry',
#  'PATH': '/root/.cache/pypoetry/virtualenvs/dve-sample-r-P4i7psD2-py3.12/bin:/opt/pyenv/plugins/pyenv-virtualenv/shims:/opt/pyenv/shims:/root/.local/state/fnm_multishells/34_1735578041011/bin:/opt/poetry/bin:/opt/pipx/bin:/opt/pyenv/bin:/opt/pyvenvs/global/bin:/opt/nodejs/bin:/opt/cargo/bin:/opt/rust/bin:/opt/venv/bin:/usr/local/nvidia/bin:/usr/local/cuda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin',
#  'NV_NVINFER_VERSION': '8.6.0.12',
#  'NV_LIBNCCL_PACKAGE_NAME': 'libnccl2',
#  'NV_LIBNCCL_PACKAGE_VERSION': '2.15.5-1',
#  'FNM_DIR': '/opt/nodejs/.fnm',
#  'FNM_MULTISHELL_PATH': '/root/.local/state/fnm_multishells/441_1735578041849',
#  'DEFAULT_USER': 'rstudio',
#  'NV_NVCC_PACKAGE_NAME': 'cuda-nvcc-11-8',
#  'FNM_LOGLEVEL': 'info',
#  'NVBLAS_CONFIG_FILE': '/etc/nvblas.conf',
#  'JPY_SESSION_NAME': '/root/work/vs/dve-sample-r/notebooks/py-demo/Untitled4.ipynb',
#  'JPY_PARENT_PID': '1',
#  'PYDEVD_USE_FRAME_EVAL': 'NO',
#  'CLICOLOR': '1',
#  'FORCE_COLOR': '1',
#  'CLICOLOR_FORCE': '1',
#  'GIT_PAGER': 'cat',
#  'MPLBACKEND': 'module://matplotlib_inline.backend_inline'}

# %%
! poetry env info
# Out:
# Virtualenv
# Python:         3.12.3
# Implementation: CPython
# Path:           /home/gp21012/.cache/pypoetry/virtualenvs/dve-sample-py-1sUhEi8s-py3.12
# Executable:     /home/gp21012/.cache/pypoetry/virtualenvs/dve-sample-py-1sUhEi8s-py3.12/bin/python
# Valid:          True
#
# Base
# Platform:   linux
# OS:         posix
# Python:     3.12.3
# Path:       /home/gp21012/.pyenv/versions/3.12.3
# Executable: /home/gp21012/.pyenv/versions/3.12.3/bin/python3.12

# %%
! poetry show --tree
# Out:
# autopep8 2.3.2 A tool that automatically formats Python code to conform to the PEP 8 style guide
# ├── pycodestyle >=2.12.0
# └── tomli *
# black 24.10.0 The uncompromising code formatter.
# ├── click >=8.0.0
# │   └── colorama *
# ├── ipython >=7.8.0
# │   ├── colorama *
# │   ├── decorator *
# │   ├── exceptiongroup *
# │   │   └── typing-extensions >=4.6.0
# │   ├── jedi >=0.16
# │   │   └── parso >=0.8.4,<0.9.0
# │   ├── matplotlib-inline *
# │   │   └── traitlets *
# │   ├── pexpect >4.3
# │   │   └── ptyprocess >=0.5
# │   ├── prompt-toolkit >=3.0.41,<3.1.0
# │   │   └── wcwidth *
# │   ├── pygments >=2.4.0
# │   ├── stack-data *
# │   │   ├── asttokens >=2.1.0
# │   │   ├── executing >=1.2.0
# │   │   └── pure-eval *
# │   ├── traitlets >=5.13.0 (circular dependency aborted here)
# │   └── typing-extensions >=4.6 (circular dependency aborted here)
# ├── mypy-extensions >=0.4.3
# ├── packaging >=22.0
# ├── pathspec >=0.9.0
# ├── platformdirs >=2
# ├── tokenize-rt >=3.2.0
# ├── tomli >=1.1.0
# └── typing-extensions >=4.0.1
# bumpversion 0.6.0 Version-bump your software with a single command!
# └── bump2version *
# click 8.1.8 Composable command line interface toolkit
# └── colorama *
# colorama 0.4.6 Cross-platform colored terminal text.
# coverage 7.6.10 Code coverage measurement for Python
# └── tomli *
# flake8 7.1.1 the modular source code checker: pep8 pyflakes and co
# ├── mccabe >=0.7.0,<0.8.0
# ├── pycodestyle >=2.12.0,<2.13.0
# └── pyflakes >=3.2.0,<3.3.0
# graphframes 0.6 GraphFrames: DataFrame-based Graphs
# ├── nose *
# └── numpy *
# graphviz 0.20.3 Simple Python interface for Graphviz
# h5py 3.12.1 Read and write HDF5 files from Python
# └── numpy >=1.19.3
# icecream 2.1.4 Never use print() to debug again; inspect variables, expressions, and program execution with a single, simple function call.
# ├── asttokens >=2.0.1
# ├── colorama >=0.3.9
# ├── executing >=2.1.0
# └── pygments >=2.2.0
# igraph 0.11.8 High performance graph data structures and algorithms
# └── texttable >=1.6.2
# ipykernel 6.29.5 IPython Kernel for Jupyter
# ├── appnope *
# ├── comm >=0.1.1
# │   └── traitlets >=4
# ├── debugpy >=1.6.5
# ├── ipython >=7.23.1
# │   ├── colorama *
# │   ├── decorator *
# │   ├── exceptiongroup *
# │   │   └── typing-extensions >=4.6.0
# │   ├── jedi >=0.16
# │   │   └── parso >=0.8.4,<0.9.0
# │   ├── matplotlib-inline *
# │   │   └── traitlets *
# │   ├── pexpect >4.3
# │   │   └── ptyprocess >=0.5
# │   ├── prompt-toolkit >=3.0.41,<3.1.0
# │   │   └── wcwidth *
# │   ├── pygments >=2.4.0
# │   ├── stack-data *
# │   │   ├── asttokens >=2.1.0
# │   │   ├── executing >=1.2.0
# │   │   └── pure-eval *
# │   ├── traitlets >=5.13.0 (circular dependency aborted here)
# │   └── typing-extensions >=4.6 (circular dependency aborted here)
# ├── jupyter-client >=6.1.12
# │   ├── jupyter-core >=4.12,<5.0.dev0 || >=5.1.dev0
# │   │   ├── platformdirs >=2.5
# │   │   ├── pywin32 >=300
# │   │   └── traitlets >=5.3
# │   ├── python-dateutil >=2.8.2
# │   │   └── six >=1.5
# │   ├── pyzmq >=23.0
# │   │   └── cffi *
# │   │       └── pycparser *
# │   ├── tornado >=6.2
# │   └── traitlets >=5.3 (circular dependency aborted here)
# ├── jupyter-core >=4.12,<5.0.dev0 || >=5.1.dev0
# │   ├── platformdirs >=2.5
# │   ├── pywin32 >=300
# │   └── traitlets >=5.3
# ├── matplotlib-inline >=0.1
# │   └── traitlets *
# ├── nest-asyncio *
# ├── packaging *
# ├── psutil *
# ├── pyzmq >=24
# │   └── cffi *
# │       └── pycparser *
# ├── tornado >=6.1
# └── traitlets >=5.4.0
# ipython 8.31.0 IPython: Productive Interactive Computing
# ├── colorama *
# ├── decorator *
# ├── exceptiongroup *
# │   └── typing-extensions >=4.6.0
# ├── jedi >=0.16
# │   └── parso >=0.8.4,<0.9.0
# ├── matplotlib-inline *
# │   └── traitlets *
# ├── pexpect >4.3
# │   └── ptyprocess >=0.5
# ├── prompt-toolkit >=3.0.41,<3.1.0
# │   └── wcwidth *
# ├── pygments >=2.4.0
# ├── stack-data *
# │   ├── asttokens >=2.1.0
# │   ├── executing >=1.2.0
# │   └── pure-eval *
# ├── traitlets >=5.13.0
# └── typing-extensions >=4.6
# ipython-bg 0.2 IPython magic to run jobs in background
# └── ipython *
#     ├── colorama *
#     ├── decorator *
#     ├── exceptiongroup *
#     │   └── typing-extensions >=4.6.0
#     ├── jedi >=0.16
#     │   └── parso >=0.8.4,<0.9.0
#     ├── matplotlib-inline *
#     │   └── traitlets *
#     ├── pexpect >4.3
#     │   └── ptyprocess >=0.5
#     ├── prompt-toolkit >=3.0.41,<3.1.0
#     │   └── wcwidth *
#     ├── pygments >=2.4.0
#     ├── stack-data *
#     │   ├── asttokens >=2.1.0
#     │   ├── executing >=1.2.0
#     │   └── pure-eval *
#     ├── traitlets >=5.13.0 (circular dependency aborted here)
#     └── typing-extensions >=4.6 (circular dependency aborted here)
# isort 5.13.2 A Python utility / library to sort Python imports.
# jedi 0.19.2 An autocompletion tool for Python that can be used for text editors.
# └── parso >=0.8.4,<0.9.0
# jupyter 1.1.1 Jupyter metapackage. Install all the Jupyter components in one go.
# ├── ipykernel *
# │   ├── appnope *
# │   ├── comm >=0.1.1
# │   │   └── traitlets >=4
# │   ├── debugpy >=1.6.5
# │   ├── ipython >=7.23.1
# │   │   ├── colorama *
# │   │   ├── decorator *
# │   │   ├── exceptiongroup *
# │   │   │   └── typing-extensions >=4.6.0
# │   │   ├── jedi >=0.16
# │   │   │   └── parso >=0.8.4,<0.9.0
# │   │   ├── matplotlib-inline *
# │   │   │   └── traitlets * (circular dependency aborted here)
# │   │   ├── pexpect >4.3
# │   │   │   └── ptyprocess >=0.5
# │   │   ├── prompt-toolkit >=3.0.41,<3.1.0
# │   │   │   └── wcwidth *
# │   │   ├── pygments >=2.4.0
# │   │   ├── stack-data *
# │   │   │   ├── asttokens >=2.1.0
# │   │   │   ├── executing >=1.2.0
# │   │   │   └── pure-eval *
# │   │   ├── traitlets >=5.13.0 (circular dependency aborted here)
# │   │   └── typing-extensions >=4.6 (circular dependency aborted here)
# │   ├── jupyter-client >=6.1.12
# │   │   ├── jupyter-core >=4.12,<5.0.dev0 || >=5.1.dev0
# │   │   │   ├── platformdirs >=2.5
# │   │   │   ├── pywin32 >=300
# │   │   │   └── traitlets >=5.3 (circular dependency aborted here)
# │   │   ├── python-dateutil >=2.8.2
# │   │   │   └── six >=1.5
# │   │   ├── pyzmq >=23.0
# │   │   │   └── cffi *
# │   │   │       └── pycparser *
# │   │   ├── tornado >=6.2
# │   │   └── traitlets >=5.3 (circular dependency aborted here)
# │   ├── jupyter-core >=4.12,<5.0.dev0 || >=5.1.dev0 (circular dependency aborted here)
# │   ├── matplotlib-inline >=0.1 (circular dependency aborted here)
# │   ├── nest-asyncio *
# │   ├── packaging *
# │   ├── psutil *
# │   ├── pyzmq >=24 (circular dependency aborted here)
# │   ├── tornado >=6.1 (circular dependency aborted here)
# │   └── traitlets >=5.4.0 (circular dependency aborted here)
# ├── ipywidgets *
# │   ├── comm >=0.1.3
# │   │   └── traitlets >=4
# │   ├── ipython >=6.1.0
# │   │   ├── colorama *
# │   │   ├── decorator *
# │   │   ├── exceptiongroup *
# │   │   │   └── typing-extensions >=4.6.0
# │   │   ├── jedi >=0.16
# │   │   │   └── parso >=0.8.4,<0.9.0
# │   │   ├── matplotlib-inline *
# │   │   │   └── traitlets * (circular dependency aborted here)
# │   │   ├── pexpect >4.3
# │   │   │   └── ptyprocess >=0.5
# │   │   ├── prompt-toolkit >=3.0.41,<3.1.0
# │   │   │   └── wcwidth *
# │   │   ├── pygments >=2.4.0
# │   │   ├── stack-data *
# │   │   │   ├── asttokens >=2.1.0
# │   │   │   ├── executing >=1.2.0
# │   │   │   └── pure-eval *
# │   │   ├── traitlets >=5.13.0 (circular dependency aborted here)
# │   │   └── typing-extensions >=4.6 (circular dependency aborted here)
# │   ├── jupyterlab-widgets >=3.0.12,<3.1.0
# │   ├── traitlets >=4.3.1 (circular dependency aborted here)
# │   └── widgetsnbextension >=4.0.12,<4.1.0
# ├── jupyter-console *
# │   ├── ipykernel >=6.14
# │   │   ├── appnope *
# │   │   ├── comm >=0.1.1
# │   │   │   └── traitlets >=4
# │   │   ├── debugpy >=1.6.5
# │   │   ├── ipython >=7.23.1
# │   │   │   ├── colorama *
# │   │   │   ├── decorator *
# │   │   │   ├── exceptiongroup *
# │   │   │   │   └── typing-extensions >=4.6.0
# │   │   │   ├── jedi >=0.16
# │   │   │   │   └── parso >=0.8.4,<0.9.0
# │   │   │   ├── matplotlib-inline *
# │   │   │   │   └── traitlets * (circular dependency aborted here)
# │   │   │   ├── pexpect >4.3
# │   │   │   │   └── ptyprocess >=0.5
# │   │   │   ├── prompt-toolkit >=3.0.41,<3.1.0
# │   │   │   │   └── wcwidth *
# │   │   │   ├── pygments >=2.4.0
# │   │   │   ├── stack-data *
# │   │   │   │   ├── asttokens >=2.1.0
# │   │   │   │   ├── executing >=1.2.0
# │   │   │   │   └── pure-eval *
# │   │   │   ├── traitlets >=5.13.0 (circular dependency aborted here)
# │   │   │   └── typing-extensions >=4.6 (circular dependency aborted here)
# │   │   ├── jupyter-client >=6.1.12
# │   │   │   ├── jupyter-core >=4.12,<5.0.dev0 || >=5.1.dev0
# │   │   │   │   ├── platformdirs >=2.5
# │   │   │   │   ├── pywin32 >=300
# │   │   │   │   └── traitlets >=5.3 (circular dependency aborted here)
# │   │   │   ├── python-dateutil >=2.8.2
# │   │   │   │   └── six >=1.5
# │   │   │   ├── pyzmq >=23.0
# │   │   │   │   └── cffi *
# │   │   │   │       └── pycparser *
# │   │   │   ├── tornado >=6.2
# │   │   │   └── traitlets >=5.3 (circular dependency aborted here)
# │   │   ├── jupyter-core >=4.12,<5.0.dev0 || >=5.1.dev0 (circular dependency aborted here)
# │   │   ├── matplotlib-inline >=0.1 (circular dependency aborted here)
# │   │   ├── nest-asyncio *
# │   │   ├── packaging *
# │   │   ├── psutil *
# │   │   ├── pyzmq >=24 (circular dependency aborted here)
# │   │   ├── tornado >=6.1 (circular dependency aborted here)
# │   │   └── traitlets >=5.4.0 (circular dependency aborted here)
# │   ├── ipython * (circular dependency aborted here)
# │   ├── jupyter-client >=7.0.0 (circular dependency aborted here)
# │   ├── jupyter-core >=4.12,<5.0.dev0 || >=5.1.dev0 (circular dependency aborted here)
# │   ├── prompt-toolkit >=3.0.30 (circular dependency aborted here)
# │   ├── pygments * (circular dependency aborted here)
# │   ├── pyzmq >=17 (circular dependency aborted here)
# │   └── traitlets >=5.4 (circular dependency aborted here)
# ├── jupyterlab *
# │   ├── async-lru >=1.0.0
# │   │   └── typing-extensions >=4.0.0
# │   ├── httpx >=0.25.0
# │   │   ├── anyio *
# │   │   │   ├── exceptiongroup >=1.0.2
# │   │   │   │   └── typing-extensions >=4.6.0 (circular dependency aborted here)
# │   │   │   ├── idna >=2.8
# │   │   │   ├── sniffio >=1.1
# │   │   │   └── typing-extensions >=4.5 (circular dependency aborted here)
# │   │   ├── certifi *
# │   │   ├── httpcore ==1.*
# │   │   │   ├── certifi * (circular dependency aborted here)
# │   │   │   └── h11 >=0.13,<0.15
# │   │   └── idna * (circular dependency aborted here)
# │   ├── ipykernel >=6.5.0
# │   │   ├── appnope *
# │   │   ├── comm >=0.1.1
# │   │   │   └── traitlets >=4
# │   │   ├── debugpy >=1.6.5
# │   │   ├── ipython >=7.23.1
# │   │   │   ├── colorama *
# │   │   │   ├── decorator *
# │   │   │   ├── exceptiongroup * (circular dependency aborted here)
# │   │   │   ├── jedi >=0.16
# │   │   │   │   └── parso >=0.8.4,<0.9.0
# │   │   │   ├── matplotlib-inline *
# │   │   │   │   └── traitlets * (circular dependency aborted here)
# │   │   │   ├── pexpect >4.3
# │   │   │   │   └── ptyprocess >=0.5
# │   │   │   ├── prompt-toolkit >=3.0.41,<3.1.0
# │   │   │   │   └── wcwidth *
# │   │   │   ├── pygments >=2.4.0
# │   │   │   ├── stack-data *
# │   │   │   │   ├── asttokens >=2.1.0
# │   │   │   │   ├── executing >=1.2.0
# │   │   │   │   └── pure-eval *
# │   │   │   ├── traitlets >=5.13.0 (circular dependency aborted here)
# │   │   │   └── typing-extensions >=4.6 (circular dependency aborted here)
# │   │   ├── jupyter-client >=6.1.12
# │   │   │   ├── jupyter-core >=4.12,<5.0.dev0 || >=5.1.dev0
# │   │   │   │   ├── platformdirs >=2.5
# │   │   │   │   ├── pywin32 >=300
# │   │   │   │   └── traitlets >=5.3 (circular dependency aborted here)
# │   │   │   ├── python-dateutil >=2.8.2
# │   │   │   │   └── six >=1.5
# │   │   │   ├── pyzmq >=23.0
# │   │   │   │   └── cffi *
# │   │   │   │       └── pycparser *
# │   │   │   ├── tornado >=6.2
# │   │   │   └── traitlets >=5.3 (circular dependency aborted here)
# │   │   ├── jupyter-core >=4.12,<5.0.dev0 || >=5.1.dev0 (circular dependency aborted here)
# │   │   ├── matplotlib-inline >=0.1 (circular dependency aborted here)
# │   │   ├── nest-asyncio *
# │   │   ├── packaging *
# │   │   ├── psutil *
# │   │   ├── pyzmq >=24 (circular dependency aborted here)
# │   │   ├── tornado >=6.1 (circular dependency aborted here)
# │   │   └── traitlets >=5.4.0 (circular dependency aborted here)
# │   ├── jinja2 >=3.0.3
# │   │   └── markupsafe >=2.0
# │   ├── jupyter-core * (circular dependency aborted here)
# │   ├── jupyter-lsp >=2.0.0
# │   │   └── jupyter-server >=1.1.2
# │   │       ├── anyio >=3.1.0 (circular dependency aborted here)
# │   │       ├── argon2-cffi >=21.1
# │   │       │   └── argon2-cffi-bindings *
# │   │       │       └── cffi >=1.0.1 (circular dependency aborted here)
# │   │       ├── jinja2 >=3.0.3 (circular dependency aborted here)
# │   │       ├── jupyter-client >=7.4.4 (circular dependency aborted here)
# │   │       ├── jupyter-core >=4.12,<5.0.dev0 || >=5.1.dev0 (circular dependency aborted here)
# │   │       ├── jupyter-events >=0.11.0
# │   │       │   ├── jsonschema >=4.18.0
# │   │       │   │   ├── attrs >=22.2.0
# │   │       │   │   ├── fqdn *
# │   │       │   │   ├── idna * (circular dependency aborted here)
# │   │       │   │   ├── isoduration *
# │   │       │   │   │   └── arrow >=0.15.0
# │   │       │   │   │       ├── python-dateutil >=2.7.0 (circular dependency aborted here)
# │   │       │   │   │       └── types-python-dateutil >=2.8.10
# │   │       │   │   ├── jsonpointer >1.13
# │   │       │   │   ├── jsonschema-specifications >=2023.3.6
# │   │       │   │   │   └── referencing >=0.31.0
# │   │       │   │   │       ├── attrs >=22.2.0 (circular dependency aborted here)
# │   │       │   │   │       └── rpds-py >=0.7.0
# │   │       │   │   ├── referencing >=0.28.4 (circular dependency aborted here)
# │   │       │   │   ├── rfc3339-validator *
# │   │       │   │   │   └── six * (circular dependency aborted here)
# │   │       │   │   ├── rfc3986-validator >0.1.0
# │   │       │   │   ├── rpds-py >=0.7.1 (circular dependency aborted here)
# │   │       │   │   ├── uri-template *
# │   │       │   │   └── webcolors >=24.6.0
# │   │       │   ├── python-json-logger >=2.0.4
# │   │       │   ├── pyyaml >=5.3
# │   │       │   ├── referencing * (circular dependency aborted here)
# │   │       │   ├── rfc3339-validator * (circular dependency aborted here)
# │   │       │   ├── rfc3986-validator >=0.1.1 (circular dependency aborted here)
# │   │       │   └── traitlets >=5.3 (circular dependency aborted here)
# │   │       ├── jupyter-server-terminals >=0.4.4
# │   │       │   ├── pywinpty >=2.0.3
# │   │       │   └── terminado >=0.8.3
# │   │       │       ├── ptyprocess * (circular dependency aborted here)
# │   │       │       ├── pywinpty >=1.1.0 (circular dependency aborted here)
# │   │       │       └── tornado >=6.1.0 (circular dependency aborted here)
# │   │       ├── nbconvert >=6.4.4
# │   │       │   ├── beautifulsoup4 *
# │   │       │   │   └── soupsieve >1.2
# │   │       │   ├── bleach !=5.0.0
# │   │       │   │   ├── tinycss2 >=1.1.0,<1.5
# │   │       │   │   │   └── webencodings >=0.4
# │   │       │   │   └── webencodings * (circular dependency aborted here)
# │   │       │   ├── defusedxml *
# │   │       │   ├── jinja2 >=3.0 (circular dependency aborted here)
# │   │       │   ├── jupyter-core >=4.7 (circular dependency aborted here)
# │   │       │   ├── jupyterlab-pygments *
# │   │       │   ├── markupsafe >=2.0 (circular dependency aborted here)
# │   │       │   ├── mistune >=2.0.3,<4
# │   │       │   │   └── typing-extensions * (circular dependency aborted here)
# │   │       │   ├── nbclient >=0.5.0
# │   │       │   │   ├── jupyter-client >=6.1.12 (circular dependency aborted here)
# │   │       │   │   ├── jupyter-core >=4.12,<5.0.dev0 || >=5.1.dev0 (circular dependency aborted here)
# │   │       │   │   ├── nbformat >=5.1
# │   │       │   │   │   ├── fastjsonschema >=2.15
# │   │       │   │   │   ├── jsonschema >=2.6 (circular dependency aborted here)
# │   │       │   │   │   ├── jupyter-core >=4.12,<5.0.dev0 || >=5.1.dev0 (circular dependency aborted here)
# │   │       │   │   │   └── traitlets >=5.1 (circular dependency aborted here)
# │   │       │   │   └── traitlets >=5.4 (circular dependency aborted here)
# │   │       │   ├── nbformat >=5.7 (circular dependency aborted here)
# │   │       │   ├── packaging * (circular dependency aborted here)
# │   │       │   ├── pandocfilters >=1.4.1
# │   │       │   ├── pygments >=2.4.1 (circular dependency aborted here)
# │   │       │   └── traitlets >=5.1 (circular dependency aborted here)
# │   │       ├── nbformat >=5.3.0 (circular dependency aborted here)
# │   │       ├── overrides >=5.0
# │   │       ├── packaging >=22.0 (circular dependency aborted here)
# │   │       ├── prometheus-client >=0.9
# │   │       ├── pywinpty >=2.0.1 (circular dependency aborted here)
# │   │       ├── pyzmq >=24 (circular dependency aborted here)
# │   │       ├── send2trash >=1.8.2
# │   │       ├── terminado >=0.8.3 (circular dependency aborted here)
# │   │       ├── tornado >=6.2.0 (circular dependency aborted here)
# │   │       ├── traitlets >=5.6.0 (circular dependency aborted here)
# │   │       └── websocket-client >=1.7
# │   ├── jupyter-server >=2.4.0,<3 (circular dependency aborted here)
# │   ├── jupyterlab-server >=2.27.1,<3
# │   │   ├── babel >=2.10
# │   │   ├── jinja2 >=3.0.3 (circular dependency aborted here)
# │   │   ├── json5 >=0.9.0
# │   │   ├── jsonschema >=4.18.0 (circular dependency aborted here)
# │   │   ├── jupyter-server >=1.21,<3 (circular dependency aborted here)
# │   │   ├── packaging >=21.3 (circular dependency aborted here)
# │   │   └── requests >=2.31
# │   │       ├── certifi >=2017.4.17 (circular dependency aborted here)
# │   │       ├── charset-normalizer >=2,<4
# │   │       ├── idna >=2.5,<4 (circular dependency aborted here)
# │   │       └── urllib3 >=1.21.1,<3
# │   ├── notebook-shim >=0.2
# │   │   └── jupyter-server >=1.8,<3 (circular dependency aborted here)
# │   ├── packaging * (circular dependency aborted here)
# │   ├── setuptools >=40.8.0
# │   ├── tomli >=1.2.2
# │   ├── tornado >=6.2.0 (circular dependency aborted here)
# │   └── traitlets * (circular dependency aborted here)
# ├── nbconvert *
# │   ├── beautifulsoup4 *
# │   │   └── soupsieve >1.2
# │   ├── bleach !=5.0.0
# │   │   ├── tinycss2 >=1.1.0,<1.5
# │   │   │   └── webencodings >=0.4
# │   │   └── webencodings * (circular dependency aborted here)
# │   ├── defusedxml *
# │   ├── jinja2 >=3.0
# │   │   └── markupsafe >=2.0
# │   ├── jupyter-core >=4.7
# │   │   ├── platformdirs >=2.5
# │   │   ├── pywin32 >=300
# │   │   └── traitlets >=5.3
# │   ├── jupyterlab-pygments *
# │   ├── markupsafe >=2.0 (circular dependency aborted here)
# │   ├── mistune >=2.0.3,<4
# │   │   └── typing-extensions *
# │   ├── nbclient >=0.5.0
# │   │   ├── jupyter-client >=6.1.12
# │   │   │   ├── jupyter-core >=4.12,<5.0.dev0 || >=5.1.dev0 (circular dependency aborted here)
# │   │   │   ├── python-dateutil >=2.8.2
# │   │   │   │   └── six >=1.5
# │   │   │   ├── pyzmq >=23.0
# │   │   │   │   └── cffi *
# │   │   │   │       └── pycparser *
# │   │   │   ├── tornado >=6.2
# │   │   │   └── traitlets >=5.3 (circular dependency aborted here)
# │   │   ├── jupyter-core >=4.12,<5.0.dev0 || >=5.1.dev0 (circular dependency aborted here)
# │   │   ├── nbformat >=5.1
# │   │   │   ├── fastjsonschema >=2.15
# │   │   │   ├── jsonschema >=2.6
# │   │   │   │   ├── attrs >=22.2.0
# │   │   │   │   ├── fqdn *
# │   │   │   │   ├── idna *
# │   │   │   │   ├── isoduration *
# │   │   │   │   │   └── arrow >=0.15.0
# │   │   │   │   │       ├── python-dateutil >=2.7.0 (circular dependency aborted here)
# │   │   │   │   │       └── types-python-dateutil >=2.8.10
# │   │   │   │   ├── jsonpointer >1.13
# │   │   │   │   ├── jsonschema-specifications >=2023.3.6
# │   │   │   │   │   └── referencing >=0.31.0
# │   │   │   │   │       ├── attrs >=22.2.0 (circular dependency aborted here)
# │   │   │   │   │       └── rpds-py >=0.7.0
# │   │   │   │   ├── referencing >=0.28.4 (circular dependency aborted here)
# │   │   │   │   ├── rfc3339-validator *
# │   │   │   │   │   └── six * (circular dependency aborted here)
# │   │   │   │   ├── rfc3986-validator >0.1.0
# │   │   │   │   ├── rpds-py >=0.7.1 (circular dependency aborted here)
# │   │   │   │   ├── uri-template *
# │   │   │   │   └── webcolors >=24.6.0
# │   │   │   ├── jupyter-core >=4.12,<5.0.dev0 || >=5.1.dev0 (circular dependency aborted here)
# │   │   │   └── traitlets >=5.1 (circular dependency aborted here)
# │   │   └── traitlets >=5.4 (circular dependency aborted here)
# │   ├── nbformat >=5.7 (circular dependency aborted here)
# │   ├── packaging *
# │   ├── pandocfilters >=1.4.1
# │   ├── pygments >=2.4.1
# │   └── traitlets >=5.1 (circular dependency aborted here)
# └── notebook *
#     ├── jupyter-server >=2.4.0,<3
#     │   ├── anyio >=3.1.0
#     │   │   ├── exceptiongroup >=1.0.2
#     │   │   │   └── typing-extensions >=4.6.0
#     │   │   ├── idna >=2.8
#     │   │   ├── sniffio >=1.1
#     │   │   └── typing-extensions >=4.5 (circular dependency aborted here)
#     │   ├── argon2-cffi >=21.1
#     │   │   └── argon2-cffi-bindings *
#     │   │       └── cffi >=1.0.1
#     │   │           └── pycparser *
#     │   ├── jinja2 >=3.0.3
#     │   │   └── markupsafe >=2.0
#     │   ├── jupyter-client >=7.4.4
#     │   │   ├── jupyter-core >=4.12,<5.0.dev0 || >=5.1.dev0
#     │   │   │   ├── platformdirs >=2.5
#     │   │   │   ├── pywin32 >=300
#     │   │   │   └── traitlets >=5.3
#     │   │   ├── python-dateutil >=2.8.2
#     │   │   │   └── six >=1.5
#     │   │   ├── pyzmq >=23.0
#     │   │   │   └── cffi * (circular dependency aborted here)
#     │   │   ├── tornado >=6.2
#     │   │   └── traitlets >=5.3 (circular dependency aborted here)
#     │   ├── jupyter-core >=4.12,<5.0.dev0 || >=5.1.dev0 (circular dependency aborted here)
#     │   ├── jupyter-events >=0.11.0
#     │   │   ├── jsonschema >=4.18.0
#     │   │   │   ├── attrs >=22.2.0
#     │   │   │   ├── fqdn *
#     │   │   │   ├── idna * (circular dependency aborted here)
#     │   │   │   ├── isoduration *
#     │   │   │   │   └── arrow >=0.15.0
#     │   │   │   │       ├── python-dateutil >=2.7.0 (circular dependency aborted here)
#     │   │   │   │       └── types-python-dateutil >=2.8.10
#     │   │   │   ├── jsonpointer >1.13
#     │   │   │   ├── jsonschema-specifications >=2023.3.6
#     │   │   │   │   └── referencing >=0.31.0
#     │   │   │   │       ├── attrs >=22.2.0 (circular dependency aborted here)
#     │   │   │   │       └── rpds-py >=0.7.0
#     │   │   │   ├── referencing >=0.28.4 (circular dependency aborted here)
#     │   │   │   ├── rfc3339-validator *
#     │   │   │   │   └── six * (circular dependency aborted here)
#     │   │   │   ├── rfc3986-validator >0.1.0
#     │   │   │   ├── rpds-py >=0.7.1 (circular dependency aborted here)
#     │   │   │   ├── uri-template *
#     │   │   │   └── webcolors >=24.6.0
#     │   │   ├── python-json-logger >=2.0.4
#     │   │   ├── pyyaml >=5.3
#     │   │   ├── referencing * (circular dependency aborted here)
#     │   │   ├── rfc3339-validator * (circular dependency aborted here)
#     │   │   ├── rfc3986-validator >=0.1.1 (circular dependency aborted here)
#     │   │   └── traitlets >=5.3 (circular dependency aborted here)
#     │   ├── jupyter-server-terminals >=0.4.4
#     │   │   ├── pywinpty >=2.0.3
#     │   │   └── terminado >=0.8.3
#     │   │       ├── ptyprocess *
#     │   │       ├── pywinpty >=1.1.0 (circular dependency aborted here)
#     │   │       └── tornado >=6.1.0 (circular dependency aborted here)
#     │   ├── nbconvert >=6.4.4
#     │   │   ├── beautifulsoup4 *
#     │   │   │   └── soupsieve >1.2
#     │   │   ├── bleach !=5.0.0
#     │   │   │   ├── tinycss2 >=1.1.0,<1.5
#     │   │   │   │   └── webencodings >=0.4
#     │   │   │   └── webencodings * (circular dependency aborted here)
#     │   │   ├── defusedxml *
#     │   │   ├── jinja2 >=3.0 (circular dependency aborted here)
#     │   │   ├── jupyter-core >=4.7 (circular dependency aborted here)
#     │   │   ├── jupyterlab-pygments *
#     │   │   ├── markupsafe >=2.0 (circular dependency aborted here)
#     │   │   ├── mistune >=2.0.3,<4
#     │   │   │   └── typing-extensions * (circular dependency aborted here)
#     │   │   ├── nbclient >=0.5.0
#     │   │   │   ├── jupyter-client >=6.1.12 (circular dependency aborted here)
#     │   │   │   ├── jupyter-core >=4.12,<5.0.dev0 || >=5.1.dev0 (circular dependency aborted here)
#     │   │   │   ├── nbformat >=5.1
#     │   │   │   │   ├── fastjsonschema >=2.15
#     │   │   │   │   ├── jsonschema >=2.6 (circular dependency aborted here)
#     │   │   │   │   ├── jupyter-core >=4.12,<5.0.dev0 || >=5.1.dev0 (circular dependency aborted here)
#     │   │   │   │   └── traitlets >=5.1 (circular dependency aborted here)
#     │   │   │   └── traitlets >=5.4 (circular dependency aborted here)
#     │   │   ├── nbformat >=5.7 (circular dependency aborted here)
#     │   │   ├── packaging *
#     │   │   ├── pandocfilters >=1.4.1
#     │   │   ├── pygments >=2.4.1
#     │   │   └── traitlets >=5.1 (circular dependency aborted here)
#     │   ├── nbformat >=5.3.0 (circular dependency aborted here)
#     │   ├── overrides >=5.0
#     │   ├── packaging >=22.0 (circular dependency aborted here)
#     │   ├── prometheus-client >=0.9
#     │   ├── pywinpty >=2.0.1 (circular dependency aborted here)
#     │   ├── pyzmq >=24 (circular dependency aborted here)
#     │   ├── send2trash >=1.8.2
#     │   ├── terminado >=0.8.3 (circular dependency aborted here)
#     │   ├── tornado >=6.2.0 (circular dependency aborted here)
#     │   ├── traitlets >=5.6.0 (circular dependency aborted here)
#     │   └── websocket-client >=1.7
#     ├── jupyterlab >=4.3.4,<4.4
#     │   ├── async-lru >=1.0.0
#     │   │   └── typing-extensions >=4.0.0 (circular dependency aborted here)
#     │   ├── httpx >=0.25.0
#     │   │   ├── anyio * (circular dependency aborted here)
#     │   │   ├── certifi *
#     │   │   ├── httpcore ==1.*
#     │   │   │   ├── certifi * (circular dependency aborted here)
#     │   │   │   └── h11 >=0.13,<0.15
#     │   │   └── idna * (circular dependency aborted here)
#     │   ├── ipykernel >=6.5.0
#     │   │   ├── appnope *
#     │   │   ├── comm >=0.1.1
#     │   │   │   └── traitlets >=4 (circular dependency aborted here)
#     │   │   ├── debugpy >=1.6.5
#     │   │   ├── ipython >=7.23.1
#     │   │   │   ├── colorama *
#     │   │   │   ├── decorator *
#     │   │   │   ├── exceptiongroup * (circular dependency aborted here)
#     │   │   │   ├── jedi >=0.16
#     │   │   │   │   └── parso >=0.8.4,<0.9.0
#     │   │   │   ├── matplotlib-inline *
#     │   │   │   │   └── traitlets * (circular dependency aborted here)
#     │   │   │   ├── pexpect >4.3
#     │   │   │   │   └── ptyprocess >=0.5 (circular dependency aborted here)
#     │   │   │   ├── prompt-toolkit >=3.0.41,<3.1.0
#     │   │   │   │   └── wcwidth *
#     │   │   │   ├── pygments >=2.4.0 (circular dependency aborted here)
#     │   │   │   ├── stack-data *
#     │   │   │   │   ├── asttokens >=2.1.0
#     │   │   │   │   ├── executing >=1.2.0
#     │   │   │   │   └── pure-eval *
#     │   │   │   ├── traitlets >=5.13.0 (circular dependency aborted here)
#     │   │   │   └── typing-extensions >=4.6 (circular dependency aborted here)
#     │   │   ├── jupyter-client >=6.1.12 (circular dependency aborted here)
#     │   │   ├── jupyter-core >=4.12,<5.0.dev0 || >=5.1.dev0 (circular dependency aborted here)
#     │   │   ├── matplotlib-inline >=0.1 (circular dependency aborted here)
#     │   │   ├── nest-asyncio *
#     │   │   ├── packaging * (circular dependency aborted here)
#     │   │   ├── psutil *
#     │   │   ├── pyzmq >=24 (circular dependency aborted here)
#     │   │   ├── tornado >=6.1 (circular dependency aborted here)
#     │   │   └── traitlets >=5.4.0 (circular dependency aborted here)
#     │   ├── jinja2 >=3.0.3 (circular dependency aborted here)
#     │   ├── jupyter-core * (circular dependency aborted here)
#     │   ├── jupyter-lsp >=2.0.0
#     │   │   └── jupyter-server >=1.1.2 (circular dependency aborted here)
#     │   ├── jupyter-server >=2.4.0,<3 (circular dependency aborted here)
#     │   ├── jupyterlab-server >=2.27.1,<3
#     │   │   ├── babel >=2.10
#     │   │   ├── jinja2 >=3.0.3 (circular dependency aborted here)
#     │   │   ├── json5 >=0.9.0
#     │   │   ├── jsonschema >=4.18.0 (circular dependency aborted here)
#     │   │   ├── jupyter-server >=1.21,<3 (circular dependency aborted here)
#     │   │   ├── packaging >=21.3 (circular dependency aborted here)
#     │   │   └── requests >=2.31
#     │   │       ├── certifi >=2017.4.17 (circular dependency aborted here)
#     │   │       ├── charset-normalizer >=2,<4
#     │   │       ├── idna >=2.5,<4 (circular dependency aborted here)
#     │   │       └── urllib3 >=1.21.1,<3
#     │   ├── notebook-shim >=0.2
#     │   │   └── jupyter-server >=1.8,<3 (circular dependency aborted here)
#     │   ├── packaging * (circular dependency aborted here)
#     │   ├── setuptools >=40.8.0
#     │   ├── tomli >=1.2.2
#     │   ├── tornado >=6.2.0 (circular dependency aborted here)
#     │   └── traitlets * (circular dependency aborted here)
#     ├── jupyterlab-server >=2.27.1,<3 (circular dependency aborted here)
#     ├── notebook-shim >=0.2,<0.3 (circular dependency aborted here)
#     └── tornado >=6.2.0 (circular dependency aborted here)
# jupyter-console 6.6.3 Jupyter terminal console
# ├── ipykernel >=6.14
# │   ├── appnope *
# │   ├── comm >=0.1.1
# │   │   └── traitlets >=4
# │   ├── debugpy >=1.6.5
# │   ├── ipython >=7.23.1
# │   │   ├── colorama *
# │   │   ├── decorator *
# │   │   ├── exceptiongroup *
# │   │   │   └── typing-extensions >=4.6.0
# │   │   ├── jedi >=0.16
# │   │   │   └── parso >=0.8.4,<0.9.0
# │   │   ├── matplotlib-inline *
# │   │   │   └── traitlets * (circular dependency aborted here)
# │   │   ├── pexpect >4.3
# │   │   │   └── ptyprocess >=0.5
# │   │   ├── prompt-toolkit >=3.0.41,<3.1.0
# │   │   │   └── wcwidth *
# │   │   ├── pygments >=2.4.0
# │   │   ├── stack-data *
# │   │   │   ├── asttokens >=2.1.0
# │   │   │   ├── executing >=1.2.0
# │   │   │   └── pure-eval *
# │   │   ├── traitlets >=5.13.0 (circular dependency aborted here)
# │   │   └── typing-extensions >=4.6 (circular dependency aborted here)
# │   ├── jupyter-client >=6.1.12
# │   │   ├── jupyter-core >=4.12,<5.0.dev0 || >=5.1.dev0
# │   │   │   ├── platformdirs >=2.5
# │   │   │   ├── pywin32 >=300
# │   │   │   └── traitlets >=5.3 (circular dependency aborted here)
# │   │   ├── python-dateutil >=2.8.2
# │   │   │   └── six >=1.5
# │   │   ├── pyzmq >=23.0
# │   │   │   └── cffi *
# │   │   │       └── pycparser *
# │   │   ├── tornado >=6.2
# │   │   └── traitlets >=5.3 (circular dependency aborted here)
# │   ├── jupyter-core >=4.12,<5.0.dev0 || >=5.1.dev0 (circular dependency aborted here)
# │   ├── matplotlib-inline >=0.1 (circular dependency aborted here)
# │   ├── nest-asyncio *
# │   ├── packaging *
# │   ├── psutil *
# │   ├── pyzmq >=24 (circular dependency aborted here)
# │   ├── tornado >=6.1 (circular dependency aborted here)
# │   └── traitlets >=5.4.0 (circular dependency aborted here)
# ├── ipython *
# │   ├── colorama *
# │   ├── decorator *
# │   ├── exceptiongroup *
# │   │   └── typing-extensions >=4.6.0
# │   ├── jedi >=0.16
# │   │   └── parso >=0.8.4,<0.9.0
# │   ├── matplotlib-inline *
# │   │   └── traitlets *
# │   ├── pexpect >4.3
# │   │   └── ptyprocess >=0.5
# │   ├── prompt-toolkit >=3.0.41,<3.1.0
# │   │   └── wcwidth *
# │   ├── pygments >=2.4.0
# │   ├── stack-data *
# │   │   ├── asttokens >=2.1.0
# │   │   ├── executing >=1.2.0
# │   │   └── pure-eval *
# │   ├── traitlets >=5.13.0 (circular dependency aborted here)
# │   └── typing-extensions >=4.6 (circular dependency aborted here)
# ├── jupyter-client >=7.0.0
# │   ├── jupyter-core >=4.12,<5.0.dev0 || >=5.1.dev0
# │   │   ├── platformdirs >=2.5
# │   │   ├── pywin32 >=300
# │   │   └── traitlets >=5.3
# │   ├── python-dateutil >=2.8.2
# │   │   └── six >=1.5
# │   ├── pyzmq >=23.0
# │   │   └── cffi *
# │   │       └── pycparser *
# │   ├── tornado >=6.2
# │   └── traitlets >=5.3 (circular dependency aborted here)
# ├── jupyter-core >=4.12,<5.0.dev0 || >=5.1.dev0
# │   ├── platformdirs >=2.5
# │   ├── pywin32 >=300
# │   └── traitlets >=5.3
# ├── prompt-toolkit >=3.0.30
# │   └── wcwidth *
# ├── pygments *
# ├── pyzmq >=17
# │   └── cffi *
# │       └── pycparser *
# └── traitlets >=5.4
# jupyter-core 5.7.2 Jupyter core package. A base package on which Jupyter projects rely.
# ├── platformdirs >=2.5
# ├── pywin32 >=300
# └── traitlets >=5.3
# jupyter-lsp 2.2.5 Multi-Language Server WebSocket proxy for Jupyter Notebook/Lab server
# └── jupyter-server >=1.1.2
#     ├── anyio >=3.1.0
#     │   ├── exceptiongroup >=1.0.2
#     │   │   └── typing-extensions >=4.6.0
#     │   ├── idna >=2.8
#     │   ├── sniffio >=1.1
#     │   └── typing-extensions >=4.5 (circular dependency aborted here)
#     ├── argon2-cffi >=21.1
#     │   └── argon2-cffi-bindings *
#     │       └── cffi >=1.0.1
#     │           └── pycparser *
#     ├── jinja2 >=3.0.3
#     │   └── markupsafe >=2.0
#     ├── jupyter-client >=7.4.4
#     │   ├── jupyter-core >=4.12,<5.0.dev0 || >=5.1.dev0
#     │   │   ├── platformdirs >=2.5
#     │   │   ├── pywin32 >=300
#     │   │   └── traitlets >=5.3
#     │   ├── python-dateutil >=2.8.2
#     │   │   └── six >=1.5
#     │   ├── pyzmq >=23.0
#     │   │   └── cffi * (circular dependency aborted here)
#     │   ├── tornado >=6.2
#     │   └── traitlets >=5.3 (circular dependency aborted here)
#     ├── jupyter-core >=4.12,<5.0.dev0 || >=5.1.dev0 (circular dependency aborted here)
#     ├── jupyter-events >=0.11.0
#     │   ├── jsonschema >=4.18.0
#     │   │   ├── attrs >=22.2.0
#     │   │   ├── fqdn *
#     │   │   ├── idna * (circular dependency aborted here)
#     │   │   ├── isoduration *
#     │   │   │   └── arrow >=0.15.0
#     │   │   │       ├── python-dateutil >=2.7.0 (circular dependency aborted here)
#     │   │   │       └── types-python-dateutil >=2.8.10
#     │   │   ├── jsonpointer >1.13
#     │   │   ├── jsonschema-specifications >=2023.3.6
#     │   │   │   └── referencing >=0.31.0
#     │   │   │       ├── attrs >=22.2.0 (circular dependency aborted here)
#     │   │   │       └── rpds-py >=0.7.0
#     │   │   ├── referencing >=0.28.4 (circular dependency aborted here)
#     │   │   ├── rfc3339-validator *
#     │   │   │   └── six * (circular dependency aborted here)
#     │   │   ├── rfc3986-validator >0.1.0
#     │   │   ├── rpds-py >=0.7.1 (circular dependency aborted here)
#     │   │   ├── uri-template *
#     │   │   └── webcolors >=24.6.0
#     │   ├── python-json-logger >=2.0.4
#     │   ├── pyyaml >=5.3
#     │   ├── referencing * (circular dependency aborted here)
#     │   ├── rfc3339-validator * (circular dependency aborted here)
#     │   ├── rfc3986-validator >=0.1.1 (circular dependency aborted here)
#     │   └── traitlets >=5.3 (circular dependency aborted here)
#     ├── jupyter-server-terminals >=0.4.4
#     │   ├── pywinpty >=2.0.3
#     │   └── terminado >=0.8.3
#     │       ├── ptyprocess *
#     │       ├── pywinpty >=1.1.0 (circular dependency aborted here)
#     │       └── tornado >=6.1.0 (circular dependency aborted here)
#     ├── nbconvert >=6.4.4
#     │   ├── beautifulsoup4 *
#     │   │   └── soupsieve >1.2
#     │   ├── bleach !=5.0.0
#     │   │   ├── tinycss2 >=1.1.0,<1.5
#     │   │   │   └── webencodings >=0.4
#     │   │   └── webencodings * (circular dependency aborted here)
#     │   ├── defusedxml *
#     │   ├── jinja2 >=3.0 (circular dependency aborted here)
#     │   ├── jupyter-core >=4.7 (circular dependency aborted here)
#     │   ├── jupyterlab-pygments *
#     │   ├── markupsafe >=2.0 (circular dependency aborted here)
#     │   ├── mistune >=2.0.3,<4
#     │   │   └── typing-extensions * (circular dependency aborted here)
#     │   ├── nbclient >=0.5.0
#     │   │   ├── jupyter-client >=6.1.12 (circular dependency aborted here)
#     │   │   ├── jupyter-core >=4.12,<5.0.dev0 || >=5.1.dev0 (circular dependency aborted here)
#     │   │   ├── nbformat >=5.1
#     │   │   │   ├── fastjsonschema >=2.15
#     │   │   │   ├── jsonschema >=2.6 (circular dependency aborted here)
#     │   │   │   ├── jupyter-core >=4.12,<5.0.dev0 || >=5.1.dev0 (circular dependency aborted here)
#     │   │   │   └── traitlets >=5.1 (circular dependency aborted here)
#     │   │   └── traitlets >=5.4 (circular dependency aborted here)
#     │   ├── nbformat >=5.7 (circular dependency aborted here)
#     │   ├── packaging *
#     │   ├── pandocfilters >=1.4.1
#     │   ├── pygments >=2.4.1
#     │   └── traitlets >=5.1 (circular dependency aborted here)
#     ├── nbformat >=5.3.0 (circular dependency aborted here)
#     ├── overrides >=5.0
#     ├── packaging >=22.0 (circular dependency aborted here)
#     ├── prometheus-client >=0.9
#     ├── pywinpty >=2.0.1 (circular dependency aborted here)
#     ├── pyzmq >=24 (circular dependency aborted here)
#     ├── send2trash >=1.8.2
#     ├── terminado >=0.8.3 (circular dependency aborted here)
#     ├── tornado >=6.2.0 (circular dependency aborted here)
#     ├── traitlets >=5.6.0 (circular dependency aborted here)
#     └── websocket-client >=1.7
# jupyterlab 4.3.4 JupyterLab computational environment
# ├── async-lru >=1.0.0
# │   └── typing-extensions >=4.0.0
# ├── httpx >=0.25.0
# │   ├── anyio *
# │   │   ├── exceptiongroup >=1.0.2
# │   │   │   └── typing-extensions >=4.6.0
# │   │   ├── idna >=2.8
# │   │   ├── sniffio >=1.1
# │   │   └── typing-extensions >=4.5 (circular dependency aborted here)
# │   ├── certifi *
# │   ├── httpcore ==1.*
# │   │   ├── certifi * (circular dependency aborted here)
# │   │   └── h11 >=0.13,<0.15
# │   └── idna * (circular dependency aborted here)
# ├── ipykernel >=6.5.0
# │   ├── appnope *
# │   ├── comm >=0.1.1
# │   │   └── traitlets >=4
# │   ├── debugpy >=1.6.5
# │   ├── ipython >=7.23.1
# │   │   ├── colorama *
# │   │   ├── decorator *
# │   │   ├── exceptiongroup *
# │   │   │   └── typing-extensions >=4.6.0
# │   │   ├── jedi >=0.16
# │   │   │   └── parso >=0.8.4,<0.9.0
# │   │   ├── matplotlib-inline *
# │   │   │   └── traitlets * (circular dependency aborted here)
# │   │   ├── pexpect >4.3
# │   │   │   └── ptyprocess >=0.5
# │   │   ├── prompt-toolkit >=3.0.41,<3.1.0
# │   │   │   └── wcwidth *
# │   │   ├── pygments >=2.4.0
# │   │   ├── stack-data *
# │   │   │   ├── asttokens >=2.1.0
# │   │   │   ├── executing >=1.2.0
# │   │   │   └── pure-eval *
# │   │   ├── traitlets >=5.13.0 (circular dependency aborted here)
# │   │   └── typing-extensions >=4.6 (circular dependency aborted here)
# │   ├── jupyter-client >=6.1.12
# │   │   ├── jupyter-core >=4.12,<5.0.dev0 || >=5.1.dev0
# │   │   │   ├── platformdirs >=2.5
# │   │   │   ├── pywin32 >=300
# │   │   │   └── traitlets >=5.3 (circular dependency aborted here)
# │   │   ├── python-dateutil >=2.8.2
# │   │   │   └── six >=1.5
# │   │   ├── pyzmq >=23.0
# │   │   │   └── cffi *
# │   │   │       └── pycparser *
# │   │   ├── tornado >=6.2
# │   │   └── traitlets >=5.3 (circular dependency aborted here)
# │   ├── jupyter-core >=4.12,<5.0.dev0 || >=5.1.dev0 (circular dependency aborted here)
# │   ├── matplotlib-inline >=0.1 (circular dependency aborted here)
# │   ├── nest-asyncio *
# │   ├── packaging *
# │   ├── psutil *
# │   ├── pyzmq >=24 (circular dependency aborted here)
# │   ├── tornado >=6.1 (circular dependency aborted here)
# │   └── traitlets >=5.4.0 (circular dependency aborted here)
# ├── jinja2 >=3.0.3
# │   └── markupsafe >=2.0
# ├── jupyter-core *
# │   ├── platformdirs >=2.5
# │   ├── pywin32 >=300
# │   └── traitlets >=5.3
# ├── jupyter-lsp >=2.0.0
# │   └── jupyter-server >=1.1.2
# │       ├── anyio >=3.1.0
# │       │   ├── exceptiongroup >=1.0.2
# │       │   │   └── typing-extensions >=4.6.0
# │       │   ├── idna >=2.8
# │       │   ├── sniffio >=1.1
# │       │   └── typing-extensions >=4.5 (circular dependency aborted here)
# │       ├── argon2-cffi >=21.1
# │       │   └── argon2-cffi-bindings *
# │       │       └── cffi >=1.0.1
# │       │           └── pycparser *
# │       ├── jinja2 >=3.0.3
# │       │   └── markupsafe >=2.0
# │       ├── jupyter-client >=7.4.4
# │       │   ├── jupyter-core >=4.12,<5.0.dev0 || >=5.1.dev0
# │       │   │   ├── platformdirs >=2.5
# │       │   │   ├── pywin32 >=300
# │       │   │   └── traitlets >=5.3
# │       │   ├── python-dateutil >=2.8.2
# │       │   │   └── six >=1.5
# │       │   ├── pyzmq >=23.0
# │       │   │   └── cffi * (circular dependency aborted here)
# │       │   ├── tornado >=6.2
# │       │   └── traitlets >=5.3 (circular dependency aborted here)
# │       ├── jupyter-core >=4.12,<5.0.dev0 || >=5.1.dev0 (circular dependency aborted here)
# │       ├── jupyter-events >=0.11.0
# │       │   ├── jsonschema >=4.18.0
# │       │   │   ├── attrs >=22.2.0
# │       │   │   ├── fqdn *
# │       │   │   ├── idna * (circular dependency aborted here)
# │       │   │   ├── isoduration *
# │       │   │   │   └── arrow >=0.15.0
# │       │   │   │       ├── python-dateutil >=2.7.0 (circular dependency aborted here)
# │       │   │   │       └── types-python-dateutil >=2.8.10
# │       │   │   ├── jsonpointer >1.13
# │       │   │   ├── jsonschema-specifications >=2023.3.6
# │       │   │   │   └── referencing >=0.31.0
# │       │   │   │       ├── attrs >=22.2.0 (circular dependency aborted here)
# │       │   │   │       └── rpds-py >=0.7.0
# │       │   │   ├── referencing >=0.28.4 (circular dependency aborted here)
# │       │   │   ├── rfc3339-validator *
# │       │   │   │   └── six * (circular dependency aborted here)
# │       │   │   ├── rfc3986-validator >0.1.0
# │       │   │   ├── rpds-py >=0.7.1 (circular dependency aborted here)
# │       │   │   ├── uri-template *
# │       │   │   └── webcolors >=24.6.0
# │       │   ├── python-json-logger >=2.0.4
# │       │   ├── pyyaml >=5.3
# │       │   ├── referencing * (circular dependency aborted here)
# │       │   ├── rfc3339-validator * (circular dependency aborted here)
# │       │   ├── rfc3986-validator >=0.1.1 (circular dependency aborted here)
# │       │   └── traitlets >=5.3 (circular dependency aborted here)
# │       ├── jupyter-server-terminals >=0.4.4
# │       │   ├── pywinpty >=2.0.3
# │       │   └── terminado >=0.8.3
# │       │       ├── ptyprocess *
# │       │       ├── pywinpty >=1.1.0 (circular dependency aborted here)
# │       │       └── tornado >=6.1.0 (circular dependency aborted here)
# │       ├── nbconvert >=6.4.4
# │       │   ├── beautifulsoup4 *
# │       │   │   └── soupsieve >1.2
# │       │   ├── bleach !=5.0.0
# │       │   │   ├── tinycss2 >=1.1.0,<1.5
# │       │   │   │   └── webencodings >=0.4
# │       │   │   └── webencodings * (circular dependency aborted here)
# │       │   ├── defusedxml *
# │       │   ├── jinja2 >=3.0 (circular dependency aborted here)
# │       │   ├── jupyter-core >=4.7 (circular dependency aborted here)
# │       │   ├── jupyterlab-pygments *
# │       │   ├── markupsafe >=2.0 (circular dependency aborted here)
# │       │   ├── mistune >=2.0.3,<4
# │       │   │   └── typing-extensions * (circular dependency aborted here)
# │       │   ├── nbclient >=0.5.0
# │       │   │   ├── jupyter-client >=6.1.12 (circular dependency aborted here)
# │       │   │   ├── jupyter-core >=4.12,<5.0.dev0 || >=5.1.dev0 (circular dependency aborted here)
# │       │   │   ├── nbformat >=5.1
# │       │   │   │   ├── fastjsonschema >=2.15
# │       │   │   │   ├── jsonschema >=2.6 (circular dependency aborted here)
# │       │   │   │   ├── jupyter-core >=4.12,<5.0.dev0 || >=5.1.dev0 (circular dependency aborted here)
# │       │   │   │   └── traitlets >=5.1 (circular dependency aborted here)
# │       │   │   └── traitlets >=5.4 (circular dependency aborted here)
# │       │   ├── nbformat >=5.7 (circular dependency aborted here)
# │       │   ├── packaging *
# │       │   ├── pandocfilters >=1.4.1
# │       │   ├── pygments >=2.4.1
# │       │   └── traitlets >=5.1 (circular dependency aborted here)
# │       ├── nbformat >=5.3.0 (circular dependency aborted here)
# │       ├── overrides >=5.0
# │       ├── packaging >=22.0 (circular dependency aborted here)
# │       ├── prometheus-client >=0.9
# │       ├── pywinpty >=2.0.1 (circular dependency aborted here)
# │       ├── pyzmq >=24 (circular dependency aborted here)
# │       ├── send2trash >=1.8.2
# │       ├── terminado >=0.8.3 (circular dependency aborted here)
# │       ├── tornado >=6.2.0 (circular dependency aborted here)
# │       ├── traitlets >=5.6.0 (circular dependency aborted here)
# │       └── websocket-client >=1.7
# ├── jupyter-server >=2.4.0,<3
# │   ├── anyio >=3.1.0
# │   │   ├── exceptiongroup >=1.0.2
# │   │   │   └── typing-extensions >=4.6.0
# │   │   ├── idna >=2.8
# │   │   ├── sniffio >=1.1
# │   │   └── typing-extensions >=4.5 (circular dependency aborted here)
# │   ├── argon2-cffi >=21.1
# │   │   └── argon2-cffi-bindings *
# │   │       └── cffi >=1.0.1
# │   │           └── pycparser *
# │   ├── jinja2 >=3.0.3
# │   │   └── markupsafe >=2.0
# │   ├── jupyter-client >=7.4.4
# │   │   ├── jupyter-core >=4.12,<5.0.dev0 || >=5.1.dev0
# │   │   │   ├── platformdirs >=2.5
# │   │   │   ├── pywin32 >=300
# │   │   │   └── traitlets >=5.3
# │   │   ├── python-dateutil >=2.8.2
# │   │   │   └── six >=1.5
# │   │   ├── pyzmq >=23.0
# │   │   │   └── cffi * (circular dependency aborted here)
# │   │   ├── tornado >=6.2
# │   │   └── traitlets >=5.3 (circular dependency aborted here)
# │   ├── jupyter-core >=4.12,<5.0.dev0 || >=5.1.dev0 (circular dependency aborted here)
# │   ├── jupyter-events >=0.11.0
# │   │   ├── jsonschema >=4.18.0
# │   │   │   ├── attrs >=22.2.0
# │   │   │   ├── fqdn *
# │   │   │   ├── idna * (circular dependency aborted here)
# │   │   │   ├── isoduration *
# │   │   │   │   └── arrow >=0.15.0
# │   │   │   │       ├── python-dateutil >=2.7.0 (circular dependency aborted here)
# │   │   │   │       └── types-python-dateutil >=2.8.10
# │   │   │   ├── jsonpointer >1.13
# │   │   │   ├── jsonschema-specifications >=2023.3.6
# │   │   │   │   └── referencing >=0.31.0
# │   │   │   │       ├── attrs >=22.2.0 (circular dependency aborted here)
# │   │   │   │       └── rpds-py >=0.7.0
# │   │   │   ├── referencing >=0.28.4 (circular dependency aborted here)
# │   │   │   ├── rfc3339-validator *
# │   │   │   │   └── six * (circular dependency aborted here)
# │   │   │   ├── rfc3986-validator >0.1.0
# │   │   │   ├── rpds-py >=0.7.1 (circular dependency aborted here)
# │   │   │   ├── uri-template *
# │   │   │   └── webcolors >=24.6.0
# │   │   ├── python-json-logger >=2.0.4
# │   │   ├── pyyaml >=5.3
# │   │   ├── referencing * (circular dependency aborted here)
# │   │   ├── rfc3339-validator * (circular dependency aborted here)
# │   │   ├── rfc3986-validator >=0.1.1 (circular dependency aborted here)
# │   │   └── traitlets >=5.3 (circular dependency aborted here)
# │   ├── jupyter-server-terminals >=0.4.4
# │   │   ├── pywinpty >=2.0.3
# │   │   └── terminado >=0.8.3
# │   │       ├── ptyprocess *
# │   │       ├── pywinpty >=1.1.0 (circular dependency aborted here)
# │   │       └── tornado >=6.1.0 (circular dependency aborted here)
# │   ├── nbconvert >=6.4.4
# │   │   ├── beautifulsoup4 *
# │   │   │   └── soupsieve >1.2
# │   │   ├── bleach !=5.0.0
# │   │   │   ├── tinycss2 >=1.1.0,<1.5
# │   │   │   │   └── webencodings >=0.4
# │   │   │   └── webencodings * (circular dependency aborted here)
# │   │   ├── defusedxml *
# │   │   ├── jinja2 >=3.0 (circular dependency aborted here)
# │   │   ├── jupyter-core >=4.7 (circular dependency aborted here)
# │   │   ├── jupyterlab-pygments *
# │   │   ├── markupsafe >=2.0 (circular dependency aborted here)
# │   │   ├── mistune >=2.0.3,<4
# │   │   │   └── typing-extensions * (circular dependency aborted here)
# │   │   ├── nbclient >=0.5.0
# │   │   │   ├── jupyter-client >=6.1.12 (circular dependency aborted here)
# │   │   │   ├── jupyter-core >=4.12,<5.0.dev0 || >=5.1.dev0 (circular dependency aborted here)
# │   │   │   ├── nbformat >=5.1
# │   │   │   │   ├── fastjsonschema >=2.15
# │   │   │   │   ├── jsonschema >=2.6 (circular dependency aborted here)
# │   │   │   │   ├── jupyter-core >=4.12,<5.0.dev0 || >=5.1.dev0 (circular dependency aborted here)
# │   │   │   │   └── traitlets >=5.1 (circular dependency aborted here)
# │   │   │   └── traitlets >=5.4 (circular dependency aborted here)
# │   │   ├── nbformat >=5.7 (circular dependency aborted here)
# │   │   ├── packaging *
# │   │   ├── pandocfilters >=1.4.1
# │   │   ├── pygments >=2.4.1
# │   │   └── traitlets >=5.1 (circular dependency aborted here)
# ...
# ├── python-lsp-server >=1.4.0
# │   ├── docstring-to-markdown *
# │   ├── jedi >=0.17.2,<0.20.0
# │   │   └── parso >=0.8.4,<0.9.0
# │   ├── pluggy >=1.0.0
# │   ├── pyflakes >=3.2.0,<3.3.0
# │   ├── python-lsp-jsonrpc >=1.1.0,<2.0.0
# │   │   └── ujson >=3.0.0
# │   ├── rope >=1.11.0
# │   │   └── pytoolconfig >=1.2.2
# │   │       ├── packaging >=23.2
# │   │       ├── platformdirs >=3.11.0
# │   │       └── tomli >=2.0.1
# │   ├── ujson >=3.0.0 (circular dependency aborted here)
# │   ├── whatthepatch >=1.0.2,<2.0.0
# │   └── yapf >=0.33.0
# │       ├── platformdirs >=3.5.1 (circular dependency aborted here)
# │       └── tomli >=2.0.1 (circular dependency aborted here)
# └── tomli *
# python-lsp-server 1.12.0 Python Language Server for the Language Server Protocol
# ├── docstring-to-markdown *
# ├── jedi >=0.17.2,<0.20.0
# │   └── parso >=0.8.4,<0.9.0
# ├── pluggy >=1.0.0
# ├── pyflakes >=3.2.0,<3.3.0
# ├── python-lsp-jsonrpc >=1.1.0,<2.0.0
# │   └── ujson >=3.0.0
# ├── rope >=1.11.0
# │   └── pytoolconfig >=1.2.2
# │       ├── packaging >=23.2
# │       ├── platformdirs >=3.11.0
# │       └── tomli >=2.0.1
# ├── ujson >=3.0.0
# ├── whatthepatch >=1.0.2,<2.0.0
# └── yapf >=0.33.0
#     ├── platformdirs >=3.5.1
#     └── tomli >=2.0.1
# pyvis 0.3.2 A Python network graph visualization library
# ├── ipython >=5.3.0
# │   ├── colorama *
# │   ├── decorator *
# │   ├── exceptiongroup *
# │   │   └── typing-extensions >=4.6.0
# │   ├── jedi >=0.16
# │   │   └── parso >=0.8.4,<0.9.0
# │   ├── matplotlib-inline *
# │   │   └── traitlets *
# │   ├── pexpect >4.3
# │   │   └── ptyprocess >=0.5
# │   ├── prompt-toolkit >=3.0.41,<3.1.0
# │   │   └── wcwidth *
# │   ├── pygments >=2.4.0
# │   ├── stack-data *
# │   │   ├── asttokens >=2.1.0
# │   │   ├── executing >=1.2.0
# │   │   └── pure-eval *
# │   ├── traitlets >=5.13.0 (circular dependency aborted here)
# │   └── typing-extensions >=4.6 (circular dependency aborted here)
# ├── jinja2 >=2.9.6
# │   └── markupsafe >=2.0
# ├── jsonpickle >=1.4.1
# └── networkx >=1.11
# pyyaml 6.0.2 YAML parser and emitter for Python
# pyzmq 26.2.0 Python bindings for 0MQ
# └── cffi *
#     └── pycparser *
# requests 2.32.3 Python HTTP for Humans.
# ├── certifi >=2017.4.17
# ├── charset-normalizer >=2,<4
# ├── idna >=2.5,<4
# └── urllib3 >=1.21.1,<3
# requests-oauthlib 2.0.0 OAuthlib authentication support for Requests.
# ├── oauthlib >=3.0.0
# └── requests >=2.0.0
#     ├── certifi >=2017.4.17
#     ├── charset-normalizer >=2,<4
#     ├── idna >=2.5,<4
#     └── urllib3 >=1.21.1,<3
# rootpath 0.2.1 Python project/package root path detection.
# └── six >=1.11.0
# ruff 0.9.1 An extremely fast Python linter and code formatter, written in Rust.
# scipy 1.15.1 Fundamental algorithms for scientific computing in Python
# └── numpy >=1.23.5,<2.5
# seaborn 0.13.2 Statistical data visualization
# ├── matplotlib >=3.4,<3.6.1 || >3.6.1
# │   ├── contourpy >=1.0.1
# │   │   └── numpy >=1.23
# │   ├── cycler >=0.10
# │   ├── fonttools >=4.22.0
# │   ├── kiwisolver >=1.3.1
# │   ├── numpy >=1.23 (circular dependency aborted here)
# │   ├── packaging >=20.0
# │   ├── pillow >=8
# │   ├── pyparsing >=2.3.1
# │   └── python-dateutil >=2.7
# │       └── six >=1.5
# ├── numpy >=1.20,<1.24.0 || >1.24.0
# └── pandas >=1.2
#     ├── numpy >=1.22.4
#     ├── numpy >=1.26.0 (circular dependency aborted here)
#     ├── numpy >=1.23.2 (circular dependency aborted here)
#     ├── python-dateutil >=2.8.2
#     │   └── six >=1.5
#     ├── pytz >=2020.1
#     └── tzdata >=2022.7
# setuptools 75.8.0 Easily download, build, install, upgrade, and uninstall Python packages
# sphinx 8.1.3 Python documentation generator
# ├── alabaster >=0.7.14
# ├── babel >=2.13
# ├── colorama >=0.4.6
# ├── docutils >=0.20,<0.22
# ├── imagesize >=1.3
# ├── jinja2 >=3.1
# │   └── markupsafe >=2.0
# ├── packaging >=23.0
# ├── pygments >=2.17
# ├── requests >=2.30.0
# │   ├── certifi >=2017.4.17
# │   ├── charset-normalizer >=2,<4
# │   ├── idna >=2.5,<4
# │   └── urllib3 >=1.21.1,<3
# ├── snowballstemmer >=2.2
# ├── sphinxcontrib-applehelp >=1.0.7
# ├── sphinxcontrib-devhelp >=1.0.6
# ├── sphinxcontrib-htmlhelp >=2.0.6
# ├── sphinxcontrib-jsmath >=1.0.1
# ├── sphinxcontrib-qthelp >=1.0.6
# ├── sphinxcontrib-serializinghtml >=1.1.9
# └── tomli >=2
# sphinx-autoapi 3.4.0 Sphinx API documentation generator
# ├── astroid >=2.7
# │   └── typing-extensions >=4.0.0
# ├── astroid >=3.0.0a1
# │   └── typing-extensions >=4.0.0
# ├── jinja2 *
# │   └── markupsafe >=2.0
# ├── pyyaml *
# └── sphinx >=6.1.0
#     ├── alabaster >=0.7.14
#     ├── babel >=2.13
#     ├── colorama >=0.4.6
#     ├── docutils >=0.20,<0.22
#     ├── imagesize >=1.3
#     ├── jinja2 >=3.1
#     │   └── markupsafe >=2.0
#     ├── packaging >=23.0
#     ├── pygments >=2.17
#     ├── requests >=2.30.0
#     │   ├── certifi >=2017.4.17
#     │   ├── charset-normalizer >=2,<4
#     │   ├── idna >=2.5,<4
#     │   └── urllib3 >=1.21.1,<3
#     ├── snowballstemmer >=2.2
#     ├── sphinxcontrib-applehelp >=1.0.7
#     ├── sphinxcontrib-devhelp >=1.0.6
#     ├── sphinxcontrib-htmlhelp >=2.0.6
#     ├── sphinxcontrib-jsmath >=1.0.1
#     ├── sphinxcontrib-qthelp >=1.0.6
#     ├── sphinxcontrib-serializinghtml >=1.1.9
#     └── tomli >=2
# sphinx-rtd-theme 3.0.2 Read the Docs theme for Sphinx
# ├── docutils >0.18,<0.22
# ├── sphinx >=6,<9
# │   ├── alabaster >=0.7.14
# │   ├── babel >=2.13
# │   ├── colorama >=0.4.6
# │   ├── docutils >=0.20,<0.22
# │   ├── imagesize >=1.3
# │   ├── jinja2 >=3.1
# │   │   └── markupsafe >=2.0
# │   ├── packaging >=23.0
# │   ├── pygments >=2.17
# │   ├── requests >=2.30.0
# │   │   ├── certifi >=2017.4.17
# │   │   ├── charset-normalizer >=2,<4
# │   │   ├── idna >=2.5,<4
# │   │   └── urllib3 >=1.21.1,<3
# │   ├── snowballstemmer >=2.2
# │   ├── sphinxcontrib-applehelp >=1.0.7
# │   ├── sphinxcontrib-devhelp >=1.0.6
# │   ├── sphinxcontrib-htmlhelp >=2.0.6
# │   ├── sphinxcontrib-jsmath >=1.0.1
# │   ├── sphinxcontrib-qthelp >=1.0.6
# │   ├── sphinxcontrib-serializinghtml >=1.1.9
# │   └── tomli >=2
# └── sphinxcontrib-jquery >=4,<5
#     └── sphinx >=1.8
#         ├── alabaster >=0.7.14
#         ├── babel >=2.13
#         ├── colorama >=0.4.6
#         ├── docutils >=0.20,<0.22
#         ├── imagesize >=1.3
#         ├── jinja2 >=3.1
#         │   └── markupsafe >=2.0
#         ├── packaging >=23.0
#         ├── pygments >=2.17
#         ├── requests >=2.30.0
#         │   ├── certifi >=2017.4.17
#         │   ├── charset-normalizer >=2,<4
#         │   ├── idna >=2.5,<4
#         │   └── urllib3 >=1.21.1,<3
#         ├── snowballstemmer >=2.2
#         ├── sphinxcontrib-applehelp >=1.0.7
#         ├── sphinxcontrib-devhelp >=1.0.6
#         ├── sphinxcontrib-htmlhelp >=2.0.6
#         ├── sphinxcontrib-jsmath >=1.0.1
#         ├── sphinxcontrib-qthelp >=1.0.6
#         ├── sphinxcontrib-serializinghtml >=1.1.9
#         └── tomli >=2
# sqlalchemy 2.0.37 Database Abstraction Library
# ├── greenlet !=0.4.17
# └── typing-extensions >=4.6.0
# sympy 1.13.3 Computer algebra system (CAS) in Python
# └── mpmath >=1.1.0,<1.4
# tensorboard 2.18.0 TensorBoard lets you watch Tensors Flow
# ├── absl-py >=0.4
# ├── grpcio >=1.48.2
# ├── markdown >=2.6.8
# ├── numpy >=1.12.0
# ├── packaging *
# ├── protobuf >=3.19.6,<4.24.0 || >4.24.0
# ├── setuptools >=41.0.0
# ├── six >1.9
# ├── tensorboard-data-server >=0.7.0,<0.8.0
# └── werkzeug >=1.0.1
#     └── markupsafe >=2.1.1
# tensorflow-datasets 4.9.7 tensorflow/datasets is a library of datasets ready to use with TensorFlow.
# ├── absl-py *
# ├── array-record >=0.5.0
# │   ├── absl-py *
# │   └── etils *
# │       ├── absl-py * (circular dependency aborted here)
# │       ├── fsspec *
# │       ├── importlib-resources *
# │       ├── numpy *
# │       ├── tqdm *
# │       │   └── colorama *
# │       ├── typing-extensions *
# │       └── zipp *
# ├── click *
# │   └── colorama *
# ├── dm-tree *
# ├── etils >=1.6.0
# │   ├── absl-py *
# │   ├── fsspec *
# │   ├── importlib-resources *
# │   ├── numpy *
# │   ├── tqdm *
# │   │   └── colorama *
# │   ├── typing-extensions *
# │   └── zipp *
# ├── etils >=1.9.1
# │   ├── absl-py *
# │   ├── fsspec *
# │   ├── importlib-resources *
# │   ├── numpy *
# │   ├── tqdm *
# │   │   └── colorama *
# │   ├── typing-extensions *
# │   └── zipp *
# ├── immutabledict *
# ├── numpy *
# ├── promise *
# │   └── six *
# ├── protobuf >=3.20
# ├── psutil *
# ├── pyarrow *
# ├── requests >=2.19.0
# │   ├── certifi >=2017.4.17
# │   ├── charset-normalizer >=2,<4
# │   ├── idna >=2.5,<4
# │   └── urllib3 >=1.21.1,<3
# ├── simple-parsing *
# │   ├── docstring-parser >=0.15,<1.0
# │   └── typing-extensions >=4.5.0
# ├── tensorflow-metadata *
# │   ├── absl-py >=0.9,<3.0.0
# │   ├── googleapis-common-protos >=1.56.4,<2
# │   │   └── protobuf >=3.20.2,<4.21.1 || >4.21.1,<4.21.2 || >4.21.2,<4.21.3 || >4.21.3,<4.21.4 || >4.21.4,<4.21.5 || >4.21.5,<6.0.0.dev0
# │   ├── protobuf >=3.20.3,<4.21 (circular dependency aborted here)
# │   └── protobuf >=4.25.2,<6.0.0.dev0 (circular dependency aborted here)
# ├── termcolor *
# ├── toml *
# ├── tqdm *
# │   └── colorama *
# └── wrapt *
# tensorflow-hub 0.16.1 TensorFlow Hub is a library to foster the publication, discovery, and consumption of reusable parts of machine learning models.
# ├── numpy >=1.12.0
# ├── protobuf >=3.19.6
# └── tf-keras >=2.14.1
#     └── tensorflow >=2.18,<2.19
#         ├── absl-py >=1.0.0
#         ├── astunparse >=1.6.0
#         │   ├── six >=1.6.1,<2.0
#         │   └── wheel >=0.23.0,<1.0
#         ├── flatbuffers >=24.3.25
#         ├── gast >=0.2.1,<0.5.0 || >0.5.0,<0.5.1 || >0.5.1,<0.5.2 || >0.5.2
#         ├── google-pasta >=0.1.1
#         │   └── six * (circular dependency aborted here)
#         ├── grpcio >=1.24.3,<2.0
#         ├── h5py >=3.11.0
#         │   └── numpy >=1.19.3
#         ├── keras >=3.5.0
#         │   ├── absl-py * (circular dependency aborted here)
#         │   ├── h5py * (circular dependency aborted here)
#         │   ├── ml-dtypes *
#         │   │   ├── numpy >=1.21.2 (circular dependency aborted here)
#         │   │   ├── numpy >=1.26.0 (circular dependency aborted here)
#         │   │   └── numpy >=1.23.3 (circular dependency aborted here)
#         │   ├── namex *
#         │   ├── numpy * (circular dependency aborted here)
#         │   ├── optree *
#         │   │   └── typing-extensions >=4.5.0
#         │   ├── packaging *
#         │   └── rich *
#         │       ├── markdown-it-py >=2.2.0
#         │       │   └── mdurl >=0.1,<1.0
#         │       ├── pygments >=2.13.0,<3.0.0
#         │       └── typing-extensions >=4.0.0,<5.0 (circular dependency aborted here)
#         ├── libclang >=13.0.0
#         ├── ml-dtypes >=0.4.0,<0.5.0 (circular dependency aborted here)
#         ├── numpy >=1.26.0,<2.1.0 (circular dependency aborted here)
#         ├── opt-einsum >=2.3.2
#         ├── packaging * (circular dependency aborted here)
#         ├── protobuf >=3.20.3,<4.21.0 || >4.21.0,<4.21.1 || >4.21.1,<4.21.2 || >4.21.2,<4.21.3 || >4.21.3,<4.21.4 || >4.21.4,<4.21.5 || >4.21.5,<6.0.0.dev0
#         ├── requests >=2.21.0,<3
#         │   ├── certifi >=2017.4.17
#         │   ├── charset-normalizer >=2,<4
#         │   ├── idna >=2.5,<4
#         │   └── urllib3 >=1.21.1,<3
#         ├── setuptools *
#         ├── six >=1.12.0 (circular dependency aborted here)
#         ├── tensorboard >=2.18,<2.19
#         │   ├── absl-py >=0.4 (circular dependency aborted here)
#         │   ├── grpcio >=1.48.2 (circular dependency aborted here)
#         │   ├── markdown >=2.6.8
#         │   ├── numpy >=1.12.0 (circular dependency aborted here)
#         │   ├── packaging * (circular dependency aborted here)
#         │   ├── protobuf >=3.19.6,<4.24.0 || >4.24.0 (circular dependency aborted here)
#         │   ├── setuptools >=41.0.0 (circular dependency aborted here)
#         │   ├── six >1.9 (circular dependency aborted here)
#         │   ├── tensorboard-data-server >=0.7.0,<0.8.0
#         │   └── werkzeug >=1.0.1
#         │       └── markupsafe >=2.1.1
#         ├── tensorflow-io-gcs-filesystem >=0.23.1
#         ├── termcolor >=1.1.0
#         ├── typing-extensions >=3.6.6 (circular dependency aborted here)
#         └── wrapt >=1.11.0
# toml 0.10.2 Python Library for Tom's Obvious, Minimal Language
# torch 2.10.0+cu130 Tensors and Dynamic neural networks in Python with strong GPU acceleration
# ├── cuda-bindings 13.0.3
# │   └── cuda-pathfinder >=1.1,<2.0
# ├── filelock *
# ├── fsspec >=0.8.5
# ├── jinja2 *
# │   └── markupsafe >=2.0
# ├── networkx >=2.5.1
# ├── nvidia-cublas 13.1.0.3
# ├── nvidia-cuda-cupti 13.0.85
# ├── nvidia-cuda-nvrtc 13.0.88
# ├── nvidia-cuda-runtime 13.0.96
# ├── nvidia-cudnn-cu13 9.15.1.9
# │   └── nvidia-cublas *
# ├── nvidia-cufft 12.0.0.61
# │   └── nvidia-nvjitlink *
# ├── nvidia-cufile 1.15.1.6
# ├── nvidia-curand 10.4.0.35
# ├── nvidia-cusolver 12.0.4.66
# │   ├── nvidia-cublas *
# │   ├── nvidia-cusparse *
# │   │   └── nvidia-nvjitlink *
# │   └── nvidia-nvjitlink * (circular dependency aborted here)
# ├── nvidia-cusparse 12.6.3.3
# │   └── nvidia-nvjitlink *
# ├── nvidia-cusparselt-cu13 0.8.0
# ├── nvidia-nccl-cu13 2.28.9
# ├── nvidia-nvjitlink 13.0.88
# ├── nvidia-nvshmem-cu13 3.4.5
# ├── nvidia-nvtx 13.0.85
# ├── setuptools *
# ├── sympy >=1.13.3
# │   └── mpmath >=1.1.0,<1.4
# ├── triton 3.6.0
# └── typing-extensions >=4.10.0
# torchvision 0.25.0+cu130 image and video datasets and models for torch deep learning
# ├── numpy *
# ├── pillow >=5.3.0,<8.3.dev0 || >=8.4.dev0
# └── torch 2.10.0
#     ├── cuda-bindings 13.0.3
#     │   └── cuda-pathfinder >=1.1,<2.0
#     ├── filelock *
#     ├── fsspec >=0.8.5
#     ├── jinja2 *
#     │   └── markupsafe >=2.0
#     ├── networkx >=2.5.1
#     ├── nvidia-cublas 13.1.0.3
#     ├── nvidia-cuda-cupti 13.0.85
#     ├── nvidia-cuda-nvrtc 13.0.88
#     ├── nvidia-cuda-runtime 13.0.96
#     ├── nvidia-cudnn-cu13 9.15.1.9
#     │   └── nvidia-cublas * (circular dependency aborted here)
#     ├── nvidia-cufft 12.0.0.61
#     │   └── nvidia-nvjitlink *
#     ├── nvidia-cufile 1.15.1.6
#     ├── nvidia-curand 10.4.0.35
#     ├── nvidia-cusolver 12.0.4.66
#     │   ├── nvidia-cublas * (circular dependency aborted here)
#     │   ├── nvidia-cusparse *
#     │   │   └── nvidia-nvjitlink * (circular dependency aborted here)
#     │   └── nvidia-nvjitlink * (circular dependency aborted here)
#     ├── nvidia-cusparse 12.6.3.3 (circular dependency aborted here)
#     ├── nvidia-cusparselt-cu13 0.8.0
#     ├── nvidia-nccl-cu13 2.28.9
#     ├── nvidia-nvjitlink 13.0.88 (circular dependency aborted here)
#     ├── nvidia-nvshmem-cu13 3.4.5
#     ├── nvidia-nvtx 13.0.85
#     ├── setuptools *
#     ├── sympy >=1.13.3
#     │   └── mpmath >=1.1.0,<1.4
#     ├── triton 3.6.0
#     └── typing-extensions >=4.10.0
# tqdm 4.67.1 Fast, Extensible Progress Meter
# └── colorama *
# twine 6.0.1 Collection of utilities for publishing packages on PyPI
# ├── keyring >=15.1
# │   ├── importlib-metadata >=4.11.4
# │   │   └── zipp >=3.20
# │   ├── jaraco-classes *
# │   │   └── more-itertools *
# │   ├── jaraco-context *
# │   │   └── backports-tarfile *
# │   ├── jaraco-functools *
# │   │   └── more-itertools * (circular dependency aborted here)
# │   ├── jeepney >=0.4.2
# │   ├── pywin32-ctypes >=0.2.0
# │   └── secretstorage >=3.2
# │       ├── cryptography >=2.0
# │       │   └── cffi >=1.12
# │       │       └── pycparser *
# │       └── jeepney >=0.6 (circular dependency aborted here)
# ├── packaging *
# ├── pkginfo >=1.8.1
# ├── readme-renderer >=35.0
# │   ├── docutils >=0.21.2
# │   ├── nh3 >=0.2.14
# │   └── pygments >=2.5.1
# ├── requests >=2.20
# │   ├── certifi >=2017.4.17
# │   ├── charset-normalizer >=2,<4
# │   ├── idna >=2.5,<4
# │   └── urllib3 >=1.21.1,<3
# ├── requests-toolbelt >=0.8.0,<0.9.0 || >0.9.0
# │   └── requests >=2.0.1,<3.0.0
# │       ├── certifi >=2017.4.17
# │       ├── charset-normalizer >=2,<4
# │       ├── idna >=2.5,<4
# │       └── urllib3 >=1.21.1,<3
# ├── rfc3986 >=1.4.0
# ├── rich >=12.0.0
# │   ├── markdown-it-py >=2.2.0
# │   │   └── mdurl >=0.1,<1.0
# │   ├── pygments >=2.13.0,<3.0.0
# │   └── typing-extensions >=4.0.0,<5.0
# └── urllib3 >=1.26.0
# unittest2 1.1.0 The new features in unittest backported to Python 2.4+.
# ├── argparse *
# ├── six >=1.4
# └── traceback2 *
#     └── linecache2 *
# urllib3 2.3.0 HTTP library with thread-safe connection pooling, file post, and more.
# wheel 0.45.1 A built-package format for Python
# yapf 0.43.0 A formatter for Python code
# ├── platformdirs >=3.5.1
# └── tomli >=2.0.1
