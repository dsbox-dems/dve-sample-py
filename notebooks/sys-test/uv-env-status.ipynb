# %%
import sys

# %%
sys.version
# Out:
# '3.14.3 (main, Mar  3 2026, 14:59:53) [Clang 21.1.4 ]'

# %%
sys.path
# Out:
# ['/home/gp21012/.local/share/uv/python/cpython-3.14.3-linux-x86_64-gnu/lib/python314.zip',
#  '/home/gp21012/.local/share/uv/python/cpython-3.14.3-linux-x86_64-gnu/lib/python3.14',
#  '/home/gp21012/.local/share/uv/python/cpython-3.14.3-linux-x86_64-gnu/lib/python3.14/lib-dynload',
#  '',
#  '/home/gp21012/work/vs/dve-sample-py/.venv/lib/python3.14/site-packages']

# %%
import pkg_resources
installed_packages = pkg_resources.working_set
installed_packages_list = sorted(["%s==%s" % (i.key, i.version)
     for i in installed_packages])
print(installed_packages_list)
# Out:
# ['altair==6.0.0', 'anyio==4.12.1', 'argon2-cffi-bindings==25.1.0', 'argon2-cffi==25.1.0', 'arrow==1.4.0', 'asttokens==3.0.1', 'async-lru==2.2.0', 'attrs==25.4.0', 'autopep8==2.3.2', 'babel==2.18.0', 'beautifulsoup4==4.14.3', 'behave==1.3.3', 'bleach==6.3.0', 'bump2version==1.0.1', 'bumpversion==0.6.0', 'certifi==2022.12.7', 'cffi==2.0.0', 'charset-normalizer==2.1.1', 'click==8.3.1', 'colorama==0.4.6', 'comm==0.2.3', 'contourpy==1.3.3', 'coverage==7.13.4', 'cryptography==46.0.5', 'cucumber-expressions==19.0.0', 'cucumber-tag-expressions==9.1.0', 'cuda-bindings==13.0.3', 'cuda-pathfinder==1.2.2', 'cycler==0.12.1', 'debugpy==1.8.20', 'decorator==5.2.1', 'defusedxml==0.7.1', 'docutils==0.22.4', 'dve-sample-py==0.1.0', 'et-xmlfile==2.0.0', 'executing==2.2.1', 'fastjsonschema==2.21.2', 'filelock==3.20.0', 'fonttools==4.62.1', 'fqdn==1.5.1', 'fsspec==2025.12.0', 'graphframes==0.6', 'graphviz==0.21', 'greenlet==3.3.2', 'h11==0.16.0', 'httpcore==1.0.9', 'httpx==0.28.1', 'icecream==2.1.10', 'id==1.5.0', 'idna==3.4', 'igraph==1.0.0', 'iniconfig==2.3.0', 'ipykernel==7.2.0', 'ipython-bg==0.2', 'ipython-pygments-lexers==1.1.1', 'ipython==9.11.0', 'ipywidgets==8.1.8', 'iso3166==2.1.1', 'isoduration==20.11.0', 'jaraco-context==6.1.1', 'jaraco-functools==4.4.0', 'jaraco.classes==3.4.0', 'jedi==0.19.2', 'jeepney==0.9.0', 'jinja2==3.1.6', 'joblib==1.5.3', 'json5==0.13.0', 'jsonpickle==4.1.1', 'jsonpointer==3.0.0', 'jsonschema-specifications==2025.9.1', 'jsonschema==4.26.0', 'jupyter-client==8.8.0', 'jupyter-console==6.6.3', 'jupyter-core==5.9.1', 'jupyter-events==0.12.0', 'jupyter-lsp==2.3.0', 'jupyter-ruff==0.3.1', 'jupyter-server-terminals==0.5.4', 'jupyter-server==2.17.0', 'jupyter==1.1.1', 'jupyterlab-lsp==5.2.0', 'jupyterlab-pygments==0.3.0', 'jupyterlab-server==2.24.0', 'jupyterlab-widgets==3.0.16', 'jupyterlab==4.1.6', 'jupytext==1.19.1', 'keyring==25.7.0', 'kiwisolver==1.5.0', 'lark==1.3.1', 'librt==0.8.1', 'lux-api==0.5.1', 'lux-widget==0.1.11', 'lxml==6.0.2', 'markdown-it-py==4.0.0', 'markupsafe==3.0.3', 'matplotlib-inline==0.2.1', 'matplotlib==3.10.8', 'mdit-py-plugins==0.5.0', 'mdurl==0.1.2', 'mistune==3.2.0', 'mock==5.2.0', 'more-itertools==10.8.0', 'mpmath==1.3.0', 'mypy-extensions==1.0.0', 'mypy==1.19.1', 'mysql-connector-python==9.6.0', 'narwhals==2.18.0', 'nbclient==0.10.4', 'nbconvert==7.17.0', 'nbformat==5.10.4', 'nest-asyncio==1.6.0', 'networkx==3.6.1', 'nh3==0.3.3', 'nodeenv==1.10.0', 'nodejs==0.1.1', 'nose==1.3.7', 'notebook-shim==0.2.4', 'notebook==7.1.3', 'numpy==2.3.5', 'nvidia-cublas==13.1.0.3', 'nvidia-cuda-cupti==13.0.85', 'nvidia-cuda-nvrtc==13.0.88', 'nvidia-cuda-runtime==13.0.96', 'nvidia-cudnn-cu13==9.15.1.9', 'nvidia-cufft==12.0.0.61', 'nvidia-cufile==1.15.1.6', 'nvidia-curand==10.4.0.35', 'nvidia-cusolver==12.0.4.66', 'nvidia-cusparse==12.6.3.3', 'nvidia-cusparselt-cu13==0.8.0', 'nvidia-ml-py==13.590.48', 'nvidia-nccl-cu13==2.28.9', 'nvidia-nvjitlink==13.0.88', 'nvidia-nvshmem-cu13==3.4.5', 'nvidia-nvtx==13.0.85', 'oauthlib==3.3.1', 'openpyxl==3.1.5', 'optional-django==0.1.0', 'packaging==24.1', 'pandas-datareader==0.10.0', 'pandas==3.0.1', 'pandocfilters==1.5.1', 'parse-type==0.6.6', 'parse==1.21.1', 'parso==0.8.6', 'pathspec==1.0.4', 'pexpect==4.9.0', 'pillow==12.0.0', 'pip==26.0.1', 'platformdirs==4.9.4', 'plotly==6.6.0', 'pluggy==1.6.0', 'polars-runtime-32==1.39.0', 'polars==1.39.0', 'prometheus-client==0.24.1', 'prompt-toolkit==3.0.52', 'psutil==7.2.2', 'psycopg2-binary==2.9.11', 'ptyprocess==0.7.0', 'pure-eval==0.2.3', 'py==1.11.0', 'pyarrow==23.0.1', 'pycodestyle==2.14.0', 'pycparser==3.0', 'pydot==4.0.1', 'pygments==2.19.2', 'pynvml==13.0.1', 'pyparsing==3.3.2', 'pyright==1.1.408', 'pytest-cov==7.0.0', 'pytest==9.0.2', 'python-dateutil==2.9.0.post0', 'python-json-logger==4.0.0', 'pyvis==0.3.2', 'pyyaml==6.0.3', 'pyzmq==27.1.0', 'radian==0.6.15', 'rchitect==0.4.9', 'readme-renderer==44.0', 'referencing==0.37.0', 'requests-oauthlib==2.0.0', 'requests-toolbelt==1.0.0', 'requests==2.28.1', 'rfc3339-validator ...
# /tmp/ipykernel_488483/197848495.py:1: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   import pkg_resources

# %%
# %env
# Out:
# {'SHELL': '/bin/bash',
#  'NV_LIBCUBLAS_VERSION': '11.11.3.6-1',
#  'NVIDIA_VISIBLE_DEVICES': 'all',
#  'NV_NVML_DEV_VERSION': '11.8.86-1',
#  'NV_CUDNN_PACKAGE_NAME': 'libcudnn8',
#  'PYENV_SHELL': 'bash',
#  'USERID': '0',
#  'GLOBAL_VENV': '/opt/pyvenvs/global',
#  'NV_LIBNCCL_DEV_PACKAGE': 'libnccl-dev=2.15.5-1+cuda11.8',
#  'GROUPID': '0',
#  'FNM_ARCH': 'x64',
#  'NV_LIBNCCL_DEV_PACKAGE_VERSION': '2.15.5-1',
#  'R_HOME': '/usr/local/lib/R',
#  'HOSTNAME': '09c42182467d',
#  'X_RC_SYSPROFILE_INCLUDED': '1',
#  'NVIDIA_REQUIRE_CUDA': 'cuda>=11.8 brand=tesla,driver>=470,driver<471 brand=unknown,driver>=470,driver<471 brand=nvidia,driver>=470,driver<471 brand=nvidiartx,driver>=470,driver<471 brand=geforce,driver>=470,driver<471 brand=geforcertx,driver>=470,driver<471 brand=quadro,driver>=470,driver<471 brand=quadrortx,driver>=470,driver<471 brand=titan,driver>=470,driver<471 brand=titanrtx,driver>=470,driver<471',
#  'NV_LIBCUBLAS_DEV_PACKAGE': 'libcublas-dev-11-8=11.11.3.6-1',
#  'NV_NVTX_VERSION': '11.8.86-1',
#  'FNM_NODE_DIST_MIRROR': 'https://nodejs.org/dist',
#  'NV_CUDA_CUDART_DEV_VERSION': '11.8.89-1',
#  'NV_DRIVER_LINE': '470',
#  'NV_LIBCUSPARSE_VERSION': '11.7.5.86-1',
#  'X_AUTO_ENV': '1',
#  'NV_LIBNPP_VERSION': '11.8.0.86-1',
#  'NCCL_VERSION': '2.15.5-1',
#  'EDITOR': 'vim',
#  'PYENV_VERSION': '3.12.3',
#  'X_DEBUG_ENV': '',
#  'PWD': '/root/work/vs/dve-sample-r',
#  'PYENV_VIRTUALENV_INIT': '1',
#  'VIRTUAL_IMG': '/opt/venv.img',
#  'X_RC_Z93_PYENV': '1',
#  'NV_CUDNN_PACKAGE': 'libcudnn8=8.6.0.163-1+cuda11.8',
#  'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility',
#  'NV_NVCC_PACKAGE': 'cuda-nvcc-11-8',
#  'NV_NVPROF_DEV_PACKAGE': 'cuda-nvprof-11-8=11.8.87-1',
#  'NV_LIBNPP_PACKAGE': 'libnpp-11-8=11.8.0.86-1',
#  'NV_LIBNCCL_DEV_PACKAGE_NAME': 'libnccl-dev',
#  'TZ': 'Europe/Rome',
#  'NV_LIBCUBLAS_DEV_VERSION': '11.11.3.6-1',
#  'container': 'podman',
#  'NVIDIA_PRODUCT_NAME': 'CUDA',
#  'NVIDIA_CPU_ONLY': '1',
#  'NV_LIBCUBLAS_DEV_PACKAGE_NAME': 'libcublas-dev-11-8',
#  'NV_CUDA_CUDART_VERSION': '11.8.89-1',
#  'X_RC_SYSPROFILE_INCLUDING': '1',
#  'HOME': '/root',
#  'LANG': 'en_US.UTF-8',
#  'S6_VERSION': 'v2.1.0.2',
#  'FNM_COREPACK_ENABLED': 'false',
#  'CARGO_HOME': '/opt/cargo',
#  'X_WORK_DIR': '/root/./work/vs/dve-sample-r',
#  'NV_NVINFER_PACKAGE_ALIAS': 'libnvinfer7',
#  'VIRTUAL_ENV': '/root/.cache/pypoetry/virtualenvs/dve-sample-r-P4i7psD2-py3.12',
#  'CUDA_VERSION': '11.8.0',
#  'NV_LIBCUBLAS_PACKAGE': 'libcublas-11-8=11.11.3.6-1',
#  'NV_CUDA_NSIGHT_COMPUTE_DEV_PACKAGE': 'cuda-nsight-compute-11-8=11.8.0-1',
#  'PURGE_BUILDDEPS': 'false',
#  'RUSTUP_URL': 'https://sh.rustup.rs',
#  'X_RC_Z94_POETRY': '1',
#  'NV_LIBNPP_DEV_PACKAGE': 'libnpp-dev-11-8=11.8.0.86-1',
#  'NV_LIBCUBLAS_PACKAGE_NAME': 'libcublas-11-8',
#  'NV_NVINFER_PACKAGES': 'libnvinfer8=8.6.0.12-1+cuda11.8 libnvinfer-dev=8.6.0.12-1+cuda11.8 libnvinfer-headers-dev=8.6.0.12-1+cuda11.8 libnvinfer-headers-plugin-dev=8.6.0.12-1+cuda11.8 libnvinfer-plugin8=8.6.0.12-1+cuda11.8 libnvinfer-plugin-dev=8.6.0.12-1+cuda11.8',
#  'PASSWORD': '5gq2MQskQ45cJARF6Ci4qUwdnIahvUY9TYaFGmkrKl0q',
#  'NV_LIBNPP_DEV_VERSION': '11.8.0.86-1',
#  'RUST_ROOT': '/opt/rust',
#  'TERM': 'xterm-color',
#  'NV_LIBCUSPARSE_DEV_VERSION': '11.7.5.86-1',
#  'RUSTUP_HOME': '/opt/rust',
#  'NV_NVINFER_PACKAGE_LIST': 'libnvinfer8 libnvinfer-dev libnvinfer-headers-dev libnvinfer-headers-plugin-dev libnvinfer-plugin8 libnvinfer-plugin-dev',
#  'NV_DRIVER_DIST': '520',
#  'USER': 'root',
#  'CRAN': 'https://p3m.dev/cran/__linux__/jammy/latest',
#  'NODE_ROOT': '/opt/nodejs',
#  'LIBRARY_PATH': '/usr/local/cuda/lib64/stubs',
#  'NV_CUDNN_VERSION': '8.6.0.163',
#  'PYVENVS_ROOT': '/opt/pyvenvs',
#  'VISUAL': 'vim',
#  'ROOT': 'true',
#  'PYTHON_KEYRING_BACKEND': '<hidden>',
#  'PYTHON_CONFIGURE_OPTS': '--enable-shared',
#  'SHLVL': '0',
#  'PAGER': 'cat',
#  'NV_CUDA_LIB_VERSION': '11.8.0-1',
#  'NVARCH': 'x86_64',
#  'FNM_VERSION_FILE_STRATEGY': 'local',
#  'R_VERSION': '4.4.1',
#  'NV_CUDNN_PACKAGE_DEV': 'libcudnn8-dev=8.6.0.163-1+cuda11.8',
#  'PIPX_GLOBAL_HOME': '/opt/pipx',
#  'VIRTUAL_ENV_PROMPT': 'dve-sample-r-py3.12',
#  'PIPX_GLOBAL_BIN_DIR': '/opt/pipx/bin',
#  'NV_CUDA_COMPAT_PACKAGE': 'cuda-compat-11-8',
#  'NV_NVINFER_PACKAGE_NAME': 'libnvinfer8',
#  'NV_NVINFER_VER': '8.6.0.12-1+cuda11.8',
#  'RSTUDIO_VERSION': '2024.04.2+764',
#  'NV_LIBNCCL_PACKAGE': 'libnccl2=2.15.5-1+cuda11.8',
#  'LD_LIBRARY_PATH': '/usr/local/nvidia/lib:/usr/local/nvidia/lib64',
#  'FNM_ROOT': '/opt/fnm',
#  'FNM_RESOLVE_ENGINES': 'true',
#  'PS1': '(dve-sample-r-py3.12) ${debian_chroot:+($debian_chroot)}\\u@\\h:\\w\\$ ',
#  'PYENV_ROOT': '/opt/pyenv',
#  'NV_CUDA_NSIGHT_COMPUTE_VERSION': '11.8.0-1',
#  'DEBUGINFOD_URLS': '',
#  'NV_DRIVER_COMP': '470',
#  'NV_NVPROF_VERSION': '11.8.87-1',
#  'NV_CUDNN_PACKAGE_LIST': 'libcudnn8 libcudnn8-dev',
#  'RETICULATE_AUTOCONFIGURE': '0',
#  'POETRY_HOME': '/opt/poetry',
#  'PATH': '/root/.cache/pypoetry/virtualenvs/dve-sample-r-P4i7psD2-py3.12/bin:/opt/pyenv/plugins/pyenv-virtualenv/shims:/opt/pyenv/shims:/root/.local/state/fnm_multishells/34_1735578041011/bin:/opt/poetry/bin:/opt/pipx/bin:/opt/pyenv/bin:/opt/pyvenvs/global/bin:/opt/nodejs/bin:/opt/cargo/bin:/opt/rust/bin:/opt/venv/bin:/usr/local/nvidia/bin:/usr/local/cuda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin',
#  'NV_NVINFER_VERSION': '8.6.0.12',
#  'NV_LIBNCCL_PACKAGE_NAME': 'libnccl2',
#  'NV_LIBNCCL_PACKAGE_VERSION': '2.15.5-1',
#  'FNM_DIR': '/opt/nodejs/.fnm',
#  'FNM_MULTISHELL_PATH': '/root/.local/state/fnm_multishells/441_1735578041849',
#  'DEFAULT_USER': 'rstudio',
#  'NV_NVCC_PACKAGE_NAME': 'cuda-nvcc-11-8',
#  'FNM_LOGLEVEL': 'info',
#  'NVBLAS_CONFIG_FILE': '/etc/nvblas.conf',
#  'JPY_SESSION_NAME': '/root/work/vs/dve-sample-r/notebooks/py-demo/Untitled4.ipynb',
#  'JPY_PARENT_PID': '1',
#  'PYDEVD_USE_FRAME_EVAL': 'NO',
#  'CLICOLOR': '1',
#  'FORCE_COLOR': '1',
#  'CLICOLOR_FORCE': '1',
#  'GIT_PAGER': 'cat',
#  'MPLBACKEND': 'module://matplotlib_inline.backend_inline'}

# %%
# !uv --version; node --version; python --version; jupyter --version
# Out:
# uv 0.10.9
# v24.14.0
# Python 3.14.3
# Selected Jupyter core packages...
# IPython          : 9.11.0
# ipykernel        : 7.2.0
# ipywidgets       : 8.1.8
# jupyter_client   : 8.8.0
# jupyter_core     : 5.9.1
# jupyter_server   : 2.17.0
# jupyterlab       : 4.1.6
# nbclient         : 0.10.4
# nbconvert        : 7.17.0
# nbformat         : 5.10.4
# notebook         : 7.1.3
# qtconsole        : not installed
# traitlets        : 5.14.3

# %%
# !uv python list
# Out:
# cpython-3.15.0a6-linux-x86_64-gnu                 <download available>
# cpython-3.15.0a6+freethreaded-linux-x86_64-gnu    <download available>
# cpython-3.14.3-linux-x86_64-gnu                   /home/gp21012/.pyenv/shims/python3.14
# cpython-3.14.3-linux-x86_64-gnu                   /home/gp21012/.pyenv/shims/python3
# cpython-3.14.3-linux-x86_64-gnu                   /home/gp21012/.pyenv/shims/python
# cpython-3.14.3-linux-x86_64-gnu                   /home/gp21012/.local/bin/python3.14 -> /home/gp21012/.local/share/uv/python/cpython-3.14.3-linux-x86_64-gnu/bin/python3.14
# cpython-3.14.3-linux-x86_64-gnu                   /home/gp21012/.local/share/uv/python/cpython-3.14-linux-x86_64-gnu/bin/python3.14
# cpython-3.14.3+freethreaded-linux-x86_64-gnu      <download available>
# cpython-3.13.12-linux-x86_64-gnu                  <download available>
# cpython-3.13.12+freethreaded-linux-x86_64-gnu     <download available>
# cpython-3.12.13-linux-x86_64-gnu                  <download available>
# cpython-3.12.3-linux-x86_64-gnu                   /usr/bin/python3.12
# cpython-3.12.3-linux-x86_64-gnu                   /usr/bin/python3 -> python3.12
# cpython-3.12.3-linux-x86_64-gnu                   /home/gp21012/.pyenv/shims/python3.12
# cpython-3.11.15-linux-x86_64-gnu                  <download available>
# cpython-3.10.20-linux-x86_64-gnu                  <download available>
# cpython-3.9.25-linux-x86_64-gnu                   <download available>
# cpython-3.8.20-linux-x86_64-gnu                   <download available>
# pypy-3.11.13-linux-x86_64-gnu                     <download available>
# pypy-3.10.16-linux-x86_64-gnu                     <download available>
# pypy-3.9.19-linux-x86_64-gnu                      <download available>
# pypy-3.8.16-linux-x86_64-gnu                      <download available>
# graalpy-3.12.0-linux-x86_64-gnu                   <download available>
# graalpy-3.11.0-linux-x86_64-gnu                   <download available>
# graalpy-3.10.0-linux-x86_64-gnu                   <download available>
# graalpy-3.8.5-linux-x86_64-gnu                    <download available>

# %%
! uv pip list
# Out:
# Using Python 3.14.3 environment at: /home/gp21012/work/vs/dve-sample-py/.venv
# Package                   Version         Editable project location
# ------------------------- --------------- -----------------------------------
# altair                    6.0.0
# anyio                     4.12.1
# argon2-cffi               25.1.0
# argon2-cffi-bindings      25.1.0
# arrow                     1.4.0
# asttokens                 3.0.1
# async-lru                 2.2.0
# attrs                     25.4.0
# autopep8                  2.3.2
# babel                     2.18.0
# beautifulsoup4            4.14.3
# behave                    1.3.3
# bleach                    6.3.0
# bump2version              1.0.1
# bumpversion               0.6.0
# certifi                   2022.12.7
# cffi                      2.0.0
# charset-normalizer        2.1.1
# click                     8.3.1
# colorama                  0.4.6
# comm                      0.2.3
# contourpy                 1.3.3
# coverage                  7.13.4
# cryptography              46.0.5
# cucumber-expressions      19.0.0
# cucumber-tag-expressions  9.1.0
# cuda-bindings             13.0.3
# cuda-pathfinder           1.2.2
# cycler                    0.12.1
# debugpy                   1.8.20
# decorator                 5.2.1
# defusedxml                0.7.1
# docutils                  0.22.4
# dve-sample-py             0.1.0           /home/gp21012/work/vs/dve-sample-py
# et-xmlfile                2.0.0
# executing                 2.2.1
# fastjsonschema            2.21.2
# filelock                  3.20.0
# fonttools                 4.62.1
# fqdn                      1.5.1
# fsspec                    2025.12.0
# graphframes               0.6
# graphviz                  0.21
# greenlet                  3.3.2
# h11                       0.16.0
# httpcore                  1.0.9
# httpx                     0.28.1
# icecream                  2.1.10
# id                        1.5.0
# idna                      3.4
# igraph                    1.0.0
# iniconfig                 2.3.0
# ipykernel                 7.2.0
# ipython                   9.11.0
# ipython-bg                0.2
# ipython-pygments-lexers   1.1.1
# ipywidgets                8.1.8
# iso3166                   2.1.1
# isoduration               20.11.0
# jaraco-classes            3.4.0
# jaraco-context            6.1.1
# jaraco-functools          4.4.0
# jedi                      0.19.2
# jeepney                   0.9.0
# jinja2                    3.1.6
# joblib                    1.5.3
# json5                     0.13.0
# jsonpickle                4.1.1
# jsonpointer               3.0.0
# jsonschema                4.26.0
# jsonschema-specifications 2025.9.1
# jupyter                   1.1.1
# jupyter-client            8.8.0
# jupyter-console           6.6.3
# jupyter-core              5.9.1
# jupyter-events            0.12.0
# jupyter-lsp               2.3.0
# jupyter-ruff              0.3.1
# jupyter-server            2.17.0
# jupyter-server-terminals  0.5.4
# jupyterlab                4.1.6
# jupyterlab-lsp            5.2.0
# jupyterlab-pygments       0.3.0
# jupyterlab-server         2.24.0
# jupyterlab-widgets        3.0.16
# jupytext                  1.19.1
# keyring                   25.7.0
# kiwisolver                1.5.0
# lark                      1.3.1
# librt                     0.8.1
# lux-api                   0.5.1
# lux-widget                0.1.11
# lxml                      6.0.2
# markdown-it-py            4.0.0
# markupsafe                3.0.3
# matplotlib                3.10.8
# matplotlib-inline         0.2.1
# mdit-py-plugins           0.5.0
# mdurl                     0.1.2
# mistune                   3.2.0
# mock                      5.2.0
# more-itertools            10.8.0
# mpmath                    1.3.0
# mypy                      1.19.1
# mypy-extensions           1.0.0
# mysql-connector-python    9.6.0
# narwhals                  2.18.0
# nbclient                  0.10.4
# nbconvert                 7.17.0
# nbformat                  5.10.4
# nest-asyncio              1.6.0
# networkx                  3.6.1
# nh3                       0.3.3
# nodeenv                   1.10.0
# nodejs                    0.1.1
# nose                      1.3.7
# notebook                  7.1.3
# notebook-shim             0.2.4
# numpy                     2.3.5
# nvidia-cublas             13.1.0.3
# nvidia-cuda-cupti         13.0.85
# nvidia-cuda-nvrtc         13.0.88
# nvidia-cuda-runtime       13.0.96
# nvidia-cudnn-cu13         9.15.1.9
# nvidia-cufft              12.0.0.61
# nvidia-cufile             1.15.1.6
# nvidia-curand             10.4.0.35
# nvidia-cusolver           12.0.4.66
# nvidia-cusparse           12.6.3.3
# nvidia-cusparselt-cu13    0.8.0
# nvidia-ml-py              13.590.48
# nvidia-nccl-cu13          2.28.9
# nvidia-nvjitlink          13.0.88
# nvidia-nvshmem-cu13       3.4.5
# nvidia-nvtx               13.0.85
# oauthlib                  3.3.1
# openpyxl                  3.1.5
# optional-django           0.1.0
# packaging                 24.1
# pandas                    3.0.1
# pandas-datareader         0.10.0
# pandocfilters             1.5.1
# parse                     1.21.1
# parse-type                0.6.6
# parso                     0.8.6
# pathspec                  1.0.4
# pexpect                   4.9.0
# pillow                    12.0.0
# pip                       26.0.1
# platformdirs              4.9.4
# plotly                    6.6.0
# pluggy                    1.6.0
# polars                    1.39.0
# polars-runtime-32         1.39.0
# prometheus-client         0.24.1
# prompt-toolkit            3.0.52
# psutil                    7.2.2
# psycopg2-binary           2.9.11
# ptyprocess                0.7.0
# pure-eval                 0.2.3
# py                        1.11.0
# pyarrow                   23.0.1
# pycodestyle               2.14.0
# pycparser                 3.0
# pydot                     4.0.1
# pygments                  2.19.2
# pynvml                    13.0.1
# pyparsing                 3.3.2
# pyright                   1.1.408
# pytest                    9.0.2
# pytest-cov                7.0.0
# python-dateutil           2.9.0.post0
# python-json-logger        4.0.0
# pyvis                     0.3.2
# pyyaml                    6.0.3
# pyzmq                     27.1.0
# radian                    0.6.15
# rchitect                  0.4.9
# readme-renderer           44.0
# referencing               0.37.0
# requests                  2.28.1
# requests-oauthlib         2.0.0
# requests-toolbelt         1.0.0
# rfc3339-validator         0.1.4
# rfc3986                   2.0.0
# rfc3986-validator         0.1.1
# rfc3987-syntax            1.1.0
# rich                      14.3.3
# rootpath                  0.2.1
# rpds-py                   0.30.0
# ruff                      0.15.6
# scikit-learn              1.8.0
# scipy                     1.17.1
# seaborn                   0.13.2
# secretstorage             3.5.0
# send2trash                2.1.0
# setuptools                70.2.0
# sh                        2.2.2
# six                       1.17.0
# soupsieve                 2.8.3
# sqlalchemy                2.0.48
# stack-data                0.6.3
# sympy                     1.14.0
# terminado                 0.18.1
# texttable                 1.7.0
# threadpoolctl             3.6.0
# tinycss2                  1.4.0
# toml                      0.10.2
# torch                     2.10.0+cu130
# torchvision               0.25.0+cu130
# tornado                   6.5.5
# tqdm                      4.66.5
# traitlets                 5.14.3
# triton                    3.6.0
# twine                     6.2.0
# types-pyyaml              6.0.12.20250915
# types-toml                0.10.8.20240310
# typing-extensions         4.15.0
# tzdata                    2025.3
# uri-template              1.3.0
# urllib3                   1.26.13
# wcwidth                   0.6.0
# webcolors                 25.10.0
# webencodings              0.5.1
# websocket-client          1.9.0
# wheel                     0.46.3
# widgetsnbextension        4.0.15

# %%
# !uv tree  --no-dev
# Out:
# Resolved 245 packages in 1ms
# dve-sample-py v0.1.0
# ├── click v8.3.1
# ├── graphframes v0.6
# │   ├── nose v1.3.7
# │   └── numpy v2.3.5
# ├── graphviz v0.21
# ├── icecream v2.1.10
# │   ├── asttokens v3.0.1
# │   ├── colorama v0.4.6
# │   ├── executing v2.2.1
# │   └── pygments v2.19.2
# ├── igraph v1.0.0
# │   └── texttable v1.7.0
# ├── matplotlib v3.10.8
# │   ├── contourpy v1.3.3
# │   │   └── numpy v2.3.5
# │   ├── cycler v0.12.1
# │   ├── fonttools v4.62.1
# │   ├── kiwisolver v1.5.0
# │   ├── numpy v2.3.5
# │   ├── packaging v24.1
# │   ├── pillow v12.0.0
# │   ├── pyparsing v3.3.2
# │   └── python-dateutil v2.9.0.post0
# │       └── six v1.17.0
# ├── more-itertools v10.8.0
# ├── mysql-connector-python v9.6.0
# ├── networkx v3.6.1
# ├── numpy v2.3.5
# ├── oauthlib v3.3.1
# ├── openpyxl v3.1.5
# │   └── et-xmlfile v2.0.0
# ├── pandas v3.0.1
# │   ├── numpy v2.3.5
# │   └── python-dateutil v2.9.0.post0 (*)
# ├── pandas-datareader v0.10.0
# │   ├── lxml v6.0.2
# │   ├── pandas v3.0.1 (*)
# │   └── requests v2.28.1
# │       ├── certifi v2022.12.7
# │       ├── charset-normalizer v2.1.1
# │       ├── idna v3.4
# │       └── urllib3 v1.26.13
# ├── pathspec v1.0.4
# ├── pillow v12.0.0
# ├── pip v26.0.1
# ├── plotly v6.6.0
# │   ├── narwhals v2.18.0
# │   └── packaging v24.1
# ├── polars v1.39.0
# │   └── polars-runtime-32 v1.39.0
# ├── psycopg2-binary v2.9.11
# ├── pyarrow v23.0.1
# ├── pydot v4.0.1
# │   └── pyparsing v3.3.2
# ├── pyvis v0.3.2
# │   ├── ipython v9.11.0
# │   │   ├── decorator v5.2.1
# │   │   ├── ipython-pygments-lexers v1.1.1
# │   │   │   └── pygments v2.19.2
# │   │   ├── jedi v0.19.2
# │   │   │   └── parso v0.8.6
# │   │   ├── matplotlib-inline v0.2.1
# │   │   │   └── traitlets v5.14.3
# │   │   ├── pexpect v4.9.0
# │   │   │   └── ptyprocess v0.7.0
# │   │   ├── prompt-toolkit v3.0.52
# │   │   │   └── wcwidth v0.6.0
# │   │   ├── pygments v2.19.2
# │   │   ├── stack-data v0.6.3
# │   │   │   ├── asttokens v3.0.1
# │   │   │   ├── executing v2.2.1
# │   │   │   └── pure-eval v0.2.3
# │   │   └── traitlets v5.14.3
# │   ├── jinja2 v3.1.6
# │   │   └── markupsafe v3.0.3
# │   ├── jsonpickle v4.1.1
# │   └── networkx v3.6.1
# ├── pyyaml v6.0.3
# ├── pyzmq v27.1.0
# ├── radian v0.6.15
# │   ├── prompt-toolkit v3.0.52 (*)
# │   ├── pygments v2.19.2
# │   └── rchitect v0.4.9
# │       ├── cffi v2.0.0
# │       │   └── pycparser v3.0
# │       └── packaging v24.1
# ├── requests v2.28.1 (*)
# ├── requests-oauthlib v2.0.0
# │   ├── oauthlib v3.3.1
# │   └── requests v2.28.1 (*)
# ├── rootpath v0.2.1
# │   └── six v1.17.0
# ├── scipy v1.17.1
# │   └── numpy v2.3.5
# ├── seaborn v0.13.2
# │   ├── matplotlib v3.10.8 (*)
# │   ├── numpy v2.3.5
# │   └── pandas v3.0.1 (*)
# ├── sqlalchemy v2.0.48
# │   ├── greenlet v3.3.2
# │   └── typing-extensions v4.15.0
# ├── sympy v1.14.0
# │   └── mpmath v1.3.0
# ├── toml v0.10.2
# ├── torch v2.10.0+cu130
# │   ├── cuda-bindings v13.0.3
# │   │   └── cuda-pathfinder v1.2.2
# │   ├── filelock v3.20.0
# │   ├── fsspec v2025.12.0
# │   ├── jinja2 v3.1.6 (*)
# │   ├── networkx v3.6.1
# │   ├── nvidia-cublas v13.1.0.3
# │   ├── nvidia-cuda-cupti v13.0.85
# │   ├── nvidia-cuda-nvrtc v13.0.88
# │   ├── nvidia-cuda-runtime v13.0.96
# │   ├── nvidia-cudnn-cu13 v9.15.1.9
# │   │   └── nvidia-cublas v13.1.0.3
# │   ├── nvidia-cufft v12.0.0.61
# │   │   └── nvidia-nvjitlink v13.0.88
# │   ├── nvidia-cufile v1.15.1.6
# │   ├── nvidia-curand v10.4.0.35
# │   ├── nvidia-cusolver v12.0.4.66
# │   │   ├── nvidia-cublas v13.1.0.3
# │   │   ├── nvidia-cusparse v12.6.3.3
# │   │   │   └── nvidia-nvjitlink v13.0.88
# │   │   └── nvidia-nvjitlink v13.0.88
# │   ├── nvidia-cusparse v12.6.3.3 (*)
# │   ├── nvidia-cusparselt-cu13 v0.8.0
# │   ├── nvidia-nccl-cu13 v2.28.9
# │   ├── nvidia-nvjitlink v13.0.88
# │   ├── nvidia-nvshmem-cu13 v3.4.5
# │   ├── nvidia-nvtx v13.0.85
# │   ├── setuptools v70.2.0
# │   ├── sympy v1.14.0 (*)
# │   ├── triton v3.6.0
# │   └── typing-extensions v4.15.0
# ├── torchvision v0.25.0+cu130
# │   ├── numpy v2.3.5
# │   ├── pillow v12.0.0
# │   └── torch v2.10.0+cu130 (*)
# ├── tqdm v4.66.5
# ├── types-pyyaml v6.0.12.20250915
# ├── types-toml v0.10.8.20240310
# ├── urllib3 v1.26.13
# ├── nvidia-ml-py v13.590.48 (extra: gpumon)
# └── pynvml v13.0.1 (extra: gpumon)
#     └── nvidia-ml-py v13.590.48
# (*) Package tree already displayed

# %%
# !uv tree
# Out:
# Resolved 245 packages in 1ms
# dve-sample-py v0.1.0
# ├── click v8.3.1
# ├── graphframes v0.6
# │   ├── nose v1.3.7
# │   └── numpy v2.3.5
# ├── graphviz v0.21
# ├── icecream v2.1.10
# │   ├── asttokens v3.0.1
# │   ├── colorama v0.4.6
# │   ├── executing v2.2.1
# │   └── pygments v2.19.2
# ├── igraph v1.0.0
# │   └── texttable v1.7.0
# ├── matplotlib v3.10.8
# │   ├── contourpy v1.3.3
# │   │   └── numpy v2.3.5
# │   ├── cycler v0.12.1
# │   ├── fonttools v4.62.1
# │   ├── kiwisolver v1.5.0
# │   ├── numpy v2.3.5
# │   ├── packaging v24.1
# │   ├── pillow v12.0.0
# │   ├── pyparsing v3.3.2
# │   └── python-dateutil v2.9.0.post0
# │       └── six v1.17.0
# ├── more-itertools v10.8.0
# ├── mysql-connector-python v9.6.0
# ├── networkx v3.6.1
# ├── numpy v2.3.5
# ├── oauthlib v3.3.1
# ├── openpyxl v3.1.5
# │   └── et-xmlfile v2.0.0
# ├── pandas v3.0.1
# │   ├── numpy v2.3.5
# │   └── python-dateutil v2.9.0.post0 (*)
# ├── pandas-datareader v0.10.0
# │   ├── lxml v6.0.2
# │   ├── pandas v3.0.1 (*)
# │   └── requests v2.28.1
# │       ├── certifi v2022.12.7
# │       ├── charset-normalizer v2.1.1
# │       ├── idna v3.4
# │       └── urllib3 v1.26.13
# ├── pathspec v1.0.4
# ├── pillow v12.0.0
# ├── pip v26.0.1
# ├── plotly v6.6.0
# │   ├── narwhals v2.18.0
# │   └── packaging v24.1
# ├── polars v1.39.0
# │   └── polars-runtime-32 v1.39.0
# ├── psycopg2-binary v2.9.11
# ├── pyarrow v23.0.1
# ├── pydot v4.0.1
# │   └── pyparsing v3.3.2
# ├── pyvis v0.3.2
# │   ├── ipython v9.11.0
# │   │   ├── decorator v5.2.1
# │   │   ├── ipython-pygments-lexers v1.1.1
# │   │   │   └── pygments v2.19.2
# │   │   ├── jedi v0.19.2
# │   │   │   └── parso v0.8.6
# │   │   ├── matplotlib-inline v0.2.1
# │   │   │   └── traitlets v5.14.3
# │   │   ├── pexpect v4.9.0
# │   │   │   └── ptyprocess v0.7.0
# │   │   ├── prompt-toolkit v3.0.52
# │   │   │   └── wcwidth v0.6.0
# │   │   ├── pygments v2.19.2
# │   │   ├── stack-data v0.6.3
# │   │   │   ├── asttokens v3.0.1
# │   │   │   ├── executing v2.2.1
# │   │   │   └── pure-eval v0.2.3
# │   │   └── traitlets v5.14.3
# │   ├── jinja2 v3.1.6
# │   │   └── markupsafe v3.0.3
# │   ├── jsonpickle v4.1.1
# │   └── networkx v3.6.1
# ├── pyyaml v6.0.3
# ├── pyzmq v27.1.0
# ├── radian v0.6.15
# │   ├── prompt-toolkit v3.0.52 (*)
# │   ├── pygments v2.19.2
# │   └── rchitect v0.4.9
# │       ├── cffi v2.0.0
# │       │   └── pycparser v3.0
# │       └── packaging v24.1
# ├── requests v2.28.1 (*)
# ├── requests-oauthlib v2.0.0
# │   ├── oauthlib v3.3.1
# │   └── requests v2.28.1 (*)
# ├── rootpath v0.2.1
# │   └── six v1.17.0
# ├── scipy v1.17.1
# │   └── numpy v2.3.5
# ├── seaborn v0.13.2
# │   ├── matplotlib v3.10.8 (*)
# │   ├── numpy v2.3.5
# │   └── pandas v3.0.1 (*)
# ├── sqlalchemy v2.0.48
# │   ├── greenlet v3.3.2
# │   └── typing-extensions v4.15.0
# ├── sympy v1.14.0
# │   └── mpmath v1.3.0
# ├── toml v0.10.2
# ├── torch v2.10.0+cu130
# │   ├── cuda-bindings v13.0.3
# │   │   └── cuda-pathfinder v1.2.2
# │   ├── filelock v3.20.0
# │   ├── fsspec v2025.12.0
# │   ├── jinja2 v3.1.6 (*)
# │   ├── networkx v3.6.1
# │   ├── nvidia-cublas v13.1.0.3
# │   ├── nvidia-cuda-cupti v13.0.85
# │   ├── nvidia-cuda-nvrtc v13.0.88
# │   ├── nvidia-cuda-runtime v13.0.96
# │   ├── nvidia-cudnn-cu13 v9.15.1.9
# │   │   └── nvidia-cublas v13.1.0.3
# │   ├── nvidia-cufft v12.0.0.61
# │   │   └── nvidia-nvjitlink v13.0.88
# │   ├── nvidia-cufile v1.15.1.6
# │   ├── nvidia-curand v10.4.0.35
# │   ├── nvidia-cusolver v12.0.4.66
# │   │   ├── nvidia-cublas v13.1.0.3
# │   │   ├── nvidia-cusparse v12.6.3.3
# │   │   │   └── nvidia-nvjitlink v13.0.88
# │   │   └── nvidia-nvjitlink v13.0.88
# │   ├── nvidia-cusparse v12.6.3.3 (*)
# │   ├── nvidia-cusparselt-cu13 v0.8.0
# │   ├── nvidia-nccl-cu13 v2.28.9
# │   ├── nvidia-nvjitlink v13.0.88
# │   ├── nvidia-nvshmem-cu13 v3.4.5
# │   ├── nvidia-nvtx v13.0.85
# │   ├── setuptools v70.2.0
# │   ├── sympy v1.14.0 (*)
# │   ├── triton v3.6.0
# │   └── typing-extensions v4.15.0
# ├── torchvision v0.25.0+cu130
# │   ├── numpy v2.3.5
# │   ├── pillow v12.0.0
# │   └── torch v2.10.0+cu130 (*)
# ├── tqdm v4.66.5
# ├── types-pyyaml v6.0.12.20250915
# ├── types-toml v0.10.8.20240310
# ├── urllib3 v1.26.13
# ├── nvidia-ml-py v13.590.48 (extra: gpumon)
# ├── pynvml v13.0.1 (extra: gpumon)
# │   └── nvidia-ml-py v13.590.48
# ├── behave v1.3.3 (group: dev)
# │   ├── colorama v0.4.6
# │   ├── cucumber-expressions v19.0.0
# │   ├── cucumber-tag-expressions v9.1.0
# │   ├── parse v1.21.1
# │   ├── parse-type v0.6.6
# │   │   ├── parse v1.21.1
# │   │   └── six v1.17.0
# │   └── six v1.17.0
# ├── bumpversion v0.6.0 (group: dev)
# │   └── bump2version v1.0.1
# ├── colorama v0.4.6 (group: dev)
# ├── mock v5.2.0 (group: dev)
# ├── mypy v1.19.1 (group: dev)
# │   ├── librt v0.8.1
# │   ├── mypy-extensions v1.0.0
# │   ├── pathspec v1.0.4
# │   └── typing-extensions v4.15.0
# ├── nose v1.3.7 (group: dev)
# ├── py v1.11.0 (group: dev)
# ├── pyright v1.1.408 (group: dev)
# │   ├── nodeenv v1.10.0
# │   └── typing-extensions v4.15.0
# ├── pytest v9.0.2 (group: dev)
# │   ├── iniconfig v2.3.0
# │   ├── packaging v24.1
# │   ├── pluggy v1.6.0
# │   └── pygments v2.19.2
# ├── pytest-cov v7.0.0 (group: dev)
# │   ├── coverage[toml] v7.13.4
# │   ├── pluggy v1.6.0
# │   └── pytest v9.0.2 (*)
# ├── ruff v0.15.6 (group: dev)
# ├── setuptools v70.2.0 (group: dev)
# ├── twine v6.2.0 (group: dev)
# │   ├── id v1.5.0
# │   │   └── requests v2.28.1 (*)
# │   ├── keyring v25.7.0
# │   │   ├── jaraco-classes v3.4.0
# │   │   │   └── more-itertools v10.8.0
# │   │   ├── jaraco-context v6.1.1
# │   │   ├── jaraco-functools v4.4.0
# │   │   │   └── more-itertools v10.8.0
# │   │   ├── jeepney v0.9.0
# │   │   └── secretstorage v3.5.0
# │   │       ├── cryptography v46.0.5
# │   │       │   └── cffi v2.0.0 (*)
# │   │       └── jeepney v0.9.0
# │   ├── packaging v24.1
# │   ├── readme-renderer v44.0
# │   │   ├── docutils v0.22.4
# │   │   ├── nh3 v0.3.3
# │   │   └── pygments v2.19.2
# │   ├── requests v2.28.1 (*)
# │   ├── requests-toolbelt v1.0.0
# │   │   └── requests v2.28.1 (*)
# │   ├── rfc3986 v2.0.0
# │   ├── rich v14.3.3
# │   │   ├── markdown-it-py v4.0.0
# │   │   │   └── mdurl v0.1.2
# │   │   └── pygments v2.19.2
# │   └── urllib3 v1.26.13
# └── wheel v0.46.3 (group: dev)
#     └── packaging v24.1
# (*) Package tree already displayed

# %%
# !! uv help |\
sed -e '1,/^Commands:/d;/^Cache/,$ d' |\
awk '{print $1}' |\
xargs -I{} uv help --no-pager {} |\
tee /tmp/uv-help.txt; cat /tmp/uv-help.txt
# Out:
# []
