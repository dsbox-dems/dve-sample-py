# %%
import sys

print(sys.version)
# Out:
# 3.9.10 (main, Apr 17 2022, 00:04:01)
# [GCC 11.2.0]

# %%
import platform

print(platform.python_version())
# Out:
# 3.9.10

# %%
# !python --version
# Out:
# Python 3.9.10

# %%
import numpy as np

# %%
import pandas as pd

# %%
from sympy import *

# %%
x, y, z, t = symbols('x y z t')

# %%
integrate(exp(-x**2 - y**2), (x, -oo, oo), (y, -oo, oo))
# Out:
# pi
