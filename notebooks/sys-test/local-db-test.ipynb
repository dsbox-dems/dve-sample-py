# %%
import logging
import sys

# %%
import matplotlib.pyplot as plt

# %%
from sqlalchemy import create_engine

# %%
from dve.config import conf

# %%
logging.basicConfig(stream=sys.stderr, level=logging.DEBUG)

log = logging.getLogger(__name__)

plt.set_loglevel("info")

# %%
cnf = conf.get_config()

# %%
local_uri = conf.get_config().db("dve").uri()

# %%
print(f"local_uri: {conf.get_config().db('dve').dump()}")
print(f"local_dsc: {conf.get_config().db('dve').dump(full=True)}")
# Out:
# local_uri: mysql+mysqlconnector://dve:***@localhost:3306/dve
# local_dsc: {
#     "type": "mysql",
#     "driver": "mysqlconnector",
#     "pool": {
#         "name": "dve",
#         "size": 3
#     },
#     "host": "localhost",
#     "port": "3306",
#     "user": "dve",
#     "password": "***"
#     "database": "dve",
#     "uri": "{type}+{driver}://{user}:{password}@{host}:{port}/{database}"
# }

# %%
engine = create_engine(local_uri, echo=False)

# %%
with engine.connect() as con:
    rs = con.execute("SELECT current_timestamp()")
    for row in rs:
        print (row)
# Out:
# (datetime.datetime(2022, 11, 2, 16, 29, 15),)

# %%
qry = """

SELECT table_name, table_type, engine, TABLE_COMMENT
   FROM information_schema.tables
   Where TABLE_SCHEMA in ('mysql', 'demo', 'dve')
   order by engine desc;

"""

with engine.connect() as con:
    rs = con.execute(qry)
    for row in rs:
        print (row)
# Out:
# ('iris', 'BASE TABLE', 'InnoDB', 'Reference table')
