# %% [markdown]
# # NVIDIA system check

# %%
# !echo $PATH | tr ':' '\n'
# Out:
# /root/.cache/pypoetry/virtualenvs/dve-sample-r-P4i7psD2-py3.12/bin
# /opt/pyenv/plugins/pyenv-virtualenv/shims
# /opt/pyenv/shims
# /root/.local/state/fnm_multishells/47_1755617502614/bin
# /opt/poetry/bin
# /opt/pipx/bin
# /opt/pyenv/bin
# /opt/pyvenvs/global/bin
# /opt/nodejs/bin
# /opt/cargo/bin
# /opt/rust/bin
# /usr/local/sbin
# /usr/local/bin
# /usr/sbin
# /usr/bin
# /sbin
# /bin
# /usr/local/texlive/bin/linux

# %%
# !nvidia-smi
# Out:
# Tue Aug 19 17:39:49 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 575.57.08              Driver Version: 575.57.08      CUDA Version: 12.9     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       On  |   00000001:00:00.0 Off |                  Off |
# | N/A   33C    P8             13W /   70W |       0MiB /  16384MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !nvidia-smi --version
# Out:
# NVIDIA-SMI version  : 575.57.08
# NVML version        : 575.57
# DRIVER version      : 575.57.08
# CUDA Version        : 12.9

# %%
# !nvidia-smi -L
# Out:
# GPU 0: Tesla T4 (UUID: GPU-20f77044-826a-e732-4e97-6a3762f4517d)

# %%
# !lspci
# Out:
# 0000:00:00.0 Host bridge: Intel Corporation 440BX/ZX/DX - 82443BX/ZX/DX Host bridge (AGP disabled) (rev 03)
# 0000:00:07.0 ISA bridge: Intel Corporation 82371AB/EB/MB PIIX4 ISA (rev 01)
# 0000:00:07.1 IDE interface: Intel Corporation 82371AB/EB/MB PIIX4 IDE (rev 01)
# 0000:00:07.3 Bridge: Intel Corporation 82371AB/EB/MB PIIX4 ACPI (rev 02)
# 0000:00:08.0 VGA compatible controller: Microsoft Corporation Hyper-V virtual VGA
# 0001:00:00.0 3D controller: NVIDIA Corporation TU104GL [Tesla T4] (rev a1)

# %%
# !lsmod | grep nv
# Out:
# /bin/bash: line 1: lsmod: command not found

# %%
# !apt list --installed | grep -i -e nvidia -e cuda -e blas -e cudnn
# Out:
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
# libblas-dev/now 3.12.0-3build1.1 amd64 [installed,local]
# libblas3/now 3.12.0-3build1.1 amd64 [installed,local]
# libgslcblas0/now 2.7.1+dfsg-6ubuntu2 amd64 [installed,local]
# libopenblas-dev/now 0.3.26+ds-1 amd64 [installed,local]
# libopenblas-pthread-dev/now 0.3.26+ds-1 amd64 [installed,local]
# libopenblas0-pthread/now 0.3.26+ds-1 amd64 [installed,local]
# libopenblas0/now 0.3.26+ds-1 amd64 [installed,local]

# %%
# !nvidia-smi -q
# Out:
# ==============NVSMI LOG==============
#
# Timestamp                                 : Tue Aug 19 17:40:16 2025
# Driver Version                            : 575.57.08
# CUDA Version                              : 12.9
#
# Attached GPUs                             : 1
# GPU 00000001:00:00.0
#     Product Name                          : Tesla T4
#     Product Brand                         : NVIDIA
#     Product Architecture                  : Turing
#     Display Mode                          : Requested functionality has been deprecated
#     Display Attached                      : Yes
#     Display Active                        : Disabled
#     Persistence Mode                      : Enabled
#     Addressing Mode                       : None
#     MIG Mode
#         Current                           : N/A
#         Pending                           : N/A
#     Accounting Mode                       : Disabled
#     Accounting Mode Buffer Size           : 4000
#     Driver Model
# ...

# %%
# !poetry show
# Out:
# alabaster                     1.0.0          A light, configurable Sphinx t...
# altair                        5.5.0          Vega-Altair: A declarative sta...
# anyio                         4.9.0          High level compatibility layer...
# argon2-cffi                   25.1.0         Argon2 for Python
# argon2-cffi-bindings          21.2.0         Low-level CFFI bindings for Ar...
# argparse                      1.4.0          Python command-line parsing li...
# arrow                         1.3.0          Better dates & times for Python
# astroid                       3.3.11         An abstract syntax tree for Py...
# asttokens                     3.0.0          Annotate AST trees with source...
# async-lru                     2.0.5          Simple LRU cache for asyncio
# attrs                         25.3.0         Classes Without Boilerplate
# autopep8                      2.3.2          A tool that automatically form...
# ...

# %%
# !poetry show --tree
# Out:
# autopep8 2.3.2 A tool that automatically formats Python code to conform to the PEP 8 style guide
# └── pycodestyle >=2.12.0
# black 25.1.0 The uncompromising code formatter.
# ├── click >=8.0.0
# │   └── colorama *
# ├── ipython >=7.8.0
# │   ├── colorama *
# │   ├── decorator *
# │   ├── ipython-pygments-lexers *
# │   │   └── pygments *
# │   ├── jedi >=0.16
# │   │   └── parso >=0.8.4,<0.9.0
# │   ├── matplotlib-inline *
# │   │   └── traitlets *
# │   ├── pexpect >4.3
# │   │   └── ptyprocess >=0.5
# │   ├── prompt-toolkit >=3.0.41,<3.1.0
# │   │   └── wcwidth *
# │   ├── pygments >=2.4.0 (circular dependency aborted here)
# │   ├── stack-data *
# │   │   ├── asttokens >=2.1.0
# │   │   ├── executing >=1.2.0
# │   │   └── pure-eval *
# │   └── traitlets >=5.13.0 (circular dependency aborted here)
# ├── mypy-extensions >=0.4.3
# ├── packaging >=22.0
# ├── pathspec >=0.9.0
# ├── platformdirs >=2
# └── tokenize-rt >=3.2.0
# ...
